# %%
import numpy as np
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt

# %%
data = 'From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008'
pos = data.find('.')
print(data[pos:pos+3])
# Out:
# .ma

# %%
def simulate_brownian( S0, r, sigma, T, N, I):
    S = np.zeros( N + 1 )
    S[ 0 ] = S0
    h = T/N
    
    for t in range( 1, N+1 ):
        S[ t ] = S[ t-1 ]*exp( (r - 0.5*sigma**2)*h + sigma*np.sqrt(h)*np.standard.normal(I) )
    
    return S

def monte_carlo_asian( S0, r, sigma, T, N, I, K, option="call" ):
    
    S = np.zeros((N+1, I))
    S[0] = S0
    dt = T/N
    
    for t in range(1, N+1):
        S[t] = S[t-1] * np.exp( (r-0.5*sigma**2)*dt + sigma*np.sqrt(dt)*np.standard.normal(I))
        
    # calculate payoff at maturity 
    if( option == "call" ):
        payoff = np.maximum( S.mean(axis=0) - K, 0 )
    if( option == "put" ):
        payoff = np.maximum( k - S.mean(axis=0), 0 )
        
    # MCS estimator
    premium = np.exp(-r*T) * 1/I * np.sum(payoff)
    
    return premium
