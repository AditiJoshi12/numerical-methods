# %% [markdown]
# # Power Method
#
# ***

# %% [markdown]
# The eigenvalues of a n×n matrix $\mathbf{[A]}$ are obtained by solving its characteristic equation.
#
# $\lambda^{n}$ + $a_{n-1}$$\lambda^{n-1}$ + $a_{n-2}$$\lambda^{n-2}$ + ... + $a_{0}$ = **0**
#
# - For large values of n, polynomial equations like this one are difficult and time-consuming to solve.
# - Moreover, numerical techniques for approximating roots of polynomial equations of high degree are sensitive to rounding errors.
# - Therefore, we look at an alternative method for approximating eigenvalues.

# %% [markdown]
# ***
#
# ## Power Method
#
# - Like the Jacobi and Gauss-Seidel methods, the power method for approximating eigenvalues is iterative.
# - This method can be used only to find the eigenvalue of $\mathbf{[A]}$ that is largest in absolute value that is, the dominant eigenvalue of $\mathbf{[A]}$.
# - First, we assume that the matrix $\mathbf{[A]}$ has a dominant eigenvalue with corresponding dominant eigenvectors. Then we choose an initial approximation of one of the dominant eigenvectors of $\mathbf{[A]}$.
# - This initial approximation must be a nonzero vector in $R^{n}$.

# %% [markdown]
# ## Inverse Power Method
#
# - This method is used for calculating the smallest eigenvalue of the given matrix $\mathbf{[A]}$.
# - For a n × n matrix $\mathbf{[A]}$, with unique eigenvalue of minimum absolute magnitude can also be obtained by power method.
# - If α is dominant eigenvalue of $\mathbf{[A]}$, then $\frac{1}{|\alpha|}$ is dominant eigenvalue of $[A]^{-1}$ which is, consequently, the smallest eigenvalue of $\mathbf{[A]}$.

# %%
#importing libraries

import numpy as np
import sys
from pprint import pprint
import matplotlib.pyplot as plt

# %%
with open(r'Matrix1.txt') as f:
    a = [[int(num) for num in line.split()] for line in f]
    
a = np.array(a, float)
pprint(a)

n = len(a)
# Out:
# array([[-30.,  10.,  20.],
#        [ 10.,  40., -50.],
#        [ 20., -50., -10.]])

# %%
# this can be used if text file is not available

# a = np.array([[-30, 10, 20][10, 40, -50], [20, -50, -10]], float)

# n = len(a)

# %%
# initialising guess vector 

x = np.array([1,1,1], float)

errmax = 0.0000001

itermax = 500

# %%
# Power Method code for finding dominant eigenvalue 

def power(a,x, max_iteration, tolerable_error):
    lambda_old = 1.0
    condition = True
    step = 1
    while condition:
        # Multiplying a and x
        x = np.matmul(a,x)
        # Finding new Eigen value and Eigen vector
        lambda_new = max(abs(x))
        x = x/lambda_new
        
        # Displaying Eigen value and Eigen Vector
        print('\nIteration %d' %(step))
        print('----------')
        print('Eigen Value = %0.6f' %(lambda_new))
        print('Eigen Vector : ', x)      
        
        # Checking maximum iteration
        step = step + 1
        if step > max_iteration:
            print('Not convergent in given maximum iteration!')
            break
        
        # Calculating error
        error = abs(lambda_new - lambda_old)
        err2 = np.round(error, 7)
        print('Error = '+ str(err2))
        lambda_old = lambda_new
        condition = error > tolerable_error

# %%
A = np.array([[4, 2], [2, 4]], float)
X = [1, 0.5]
power(A, X, 100, 1.0e-6)
# Out:
# Iteration 1
# ----------
# Eigen Value = 5.000000
# Eigen Vector :  [1.  0.8]
# Error = 4.0
#
# Iteration 2
# ----------
# Eigen Value = 5.600000
# Eigen Vector :  [1.         0.92857143]
# Error = 0.6
#
# Iteration 3
# ----------
# Eigen Value = 5.857143
# Eigen Vector :  [1.         0.97560976]
# Error = 0.2571429
#
# Iteration 4
# ----------
# Eigen Value = 5.951220
# Eigen Vector :  [1.         0.99180328]
# Error = 0.0940767
#
# Iteration 5
# ----------
# Eigen Value = 5.983607
# Eigen Vector :  [1.         0.99726027]
# Error = 0.032387
#
# Iteration 6
# ----------
# Eigen Value = 5.994521
# Eigen Vector :  [1.         0.99908592]
# Error = 0.010914
#
# Iteration 7
# ----------
# Eigen Value = 5.998172
# Eigen Vector :  [1.         0.99969521]
# Error = 0.0036513
#
# Iteration 8
# ----------
# Eigen Value = 5.999390
# Eigen Vector :  [1.         0.99989839]
# Error = 0.0012186
#
# Iteration 9
# ----------
# Eigen Value = 5.999797
# Eigen Vector :  [1.         0.99996613]
# Error = 0.0004064
#
# Iteration 10
# ----------
# Eigen Value = 5.999932
# Eigen Vector :  [1.         0.99998871]
# Error = 0.0001355
#
# Iteration 11
# ----------
# Eigen Value = 5.999977
# Eigen Vector :  [1.         0.99999624]
# Error = 4.52e-05
#
# Iteration 12
# ----------
# Eigen Value = 5.999992
# Eigen Vector :  [1.         0.99999875]
# Error = 1.51e-05
#
# Iteration 13
# ----------
# Eigen Value = 5.999997
# Eigen Vector :  [1.         0.99999958]
# Error = 5e-06
#
# Iteration 14
# ----------
# Eigen Value = 5.999999
# Eigen Vector :  [1.         0.99999986]
# Error = 1.7e-06
#
# Iteration 15
# ----------
# Eigen Value = 6.000000
# Eigen Vector :  [1.         0.99999995]
# Error = 6e-07

# %%
# using power method to find the dominant eigenvalue

power(a,x, itermax, errmax)
# Out:
# Iteration 1
# ----------
# Eigen Value = 40.000000
# Eigen Vector :  [ 0.  0. -1.]
# Error = 39.0
#
# Iteration 2
# ----------
# Eigen Value = 50.000000
# Eigen Vector :  [-0.4  1.   0.2]
# Error = 10.0
#
# Iteration 3
# ----------
# Eigen Value = 60.000000
# Eigen Vector :  [ 0.43333333  0.43333333 -1.        ]
# Error = 10.0
#
# Iteration 4
# ----------
# Eigen Value = 71.666667
# Eigen Vector :  [-0.4         1.         -0.04186047]
# Error = 11.6666667
#
# Iteration 5
# ----------
# Eigen Value = 57.581395
# Eigen Vector :  [ 0.36752827  0.66155089 -1.        ]
# Error = 14.0852713
#
# Iteration 6
# ----------
# Eigen Value = 80.137318
# Eigen Vector :  [-0.30460639  1.         -0.19625038]
# Error = 22.5559229
#
# Iteration 7
# ----------
# Eigen Value = 54.129624
# Eigen Vector :  [ 0.28105099  0.86397155 -1.        ]
# Error = 26.0076942
#
# Iteration 8
# ----------
# Eigen Value = 87.369372
# Eigen Vector :  [-0.22653035  1.         -0.31564331]
# Error = 33.2397477
#
# Iteration 9
# ----------
# Eigen Value = 53.516862
# Eigen Vector :  [ 0.19588301  1.         -0.95996237]
# Error = 33.8525097
#
# Iteration 10
# ----------
# Eigen Value = 89.956949
# Eigen Vector :  [-0.16758836  1.         -0.40555751]
# Error = 36.4400868
#
# Iteration 11
# ----------
# Eigen Value = 58.601992
# Eigen Vector :  [ 0.11802501  1.         -0.84120336]
# Error = 31.354957
#
# Iteration 12
# ----------
# Eigen Value = 83.240418
# Eigen Vector :  [-0.12451664  1.         -0.47125504]
# Error = 24.6384262
#
# Iteration 13
# ----------
# Eigen Value = 62.317585
# Eigen Vector :  [ 0.06916825  1.         -0.76668218]
# Error = 20.9228326
#
# Iteration 14
# ----------
# Eigen Value = 79.025792
# Eigen Vector :  [-0.0937503   1.         -0.51818289]
# Error = 16.7082064
#
# Iteration 15
# ----------
# Eigen Value = 64.971641
# Eigen Vector :  [ 0.03769108  1.         -0.71867011]
# Error = 14.0541503
#
# Iteration 16
# ----------
# Eigen Value = 76.310416
# Eigen Vector :  [-0.07212822  1.         -0.55116299]
# Error = 11.338775
#
# Iteration 17
# ----------
# Eigen Value = 66.836867
# Eigen Vector :  [ 0.01706523  1.         -0.68720957]
# Error = 9.4735492
#
# Iteration 18
# ----------
# Eigen Value = 74.531131
# Eigen Vector :  [-0.05710565  1.         -0.57407689]
# Error = 7.6942633
#
# Iteration 19
# ----------
# Eigen Value = 68.132788
# Eigen Vector :  [ 0.00339971  1.         -0.66636557]
# Error = 6.3983426
#
# Iteration 20
# ----------
# Eigen Value = 73.352275
# Eigen Vector :  [-0.04675114  1.         -0.58987059]
# Error = 5.2194875
#
# Iteration 21
# ----------
# Eigen Value = 69.026018
# Eigen Vector :  [-0.00572071  1.         -0.65245422]
# Error = 4.3262573
#
# Iteration 22
# ----------
# Eigen Value = 72.565504
# Eigen Vector :  [-0.03965332  1.         -0.60069688]
# Error = 3.5394858
#
# Iteration 23
# ----------
# Eigen Value = 69.638311
# Eigen Vector :  [-0.01183742  1.         -0.64312441]
# Error = 2.9271931
#
# Iteration 24
# ----------
# Eigen Value = 72.037846
# Eigen Vector :  [-0.03480623  1.         -0.60809014]
# Error = 2.3995355
#
# Iteration 25
# ----------
# Eigen Value = 70.056445
# Eigen Vector :  [-0.01595308  1.         -0.6368468 ]
# Error = 1.9814014
#
# Iteration 26
# ----------
# Eigen Value = 71.682809
# Eigen Vector :  [-0.03150468  1.         -0.61312599]
# Error = 1.6263645
#
# Iteration 27
# ----------
# Eigen Value = 70.341253
# Eigen Vector :  [-0.01872841  1.         -0.63261361]
# Error = 1.3415566
#
# Iteration 28
# ----------
# Eigen Value = 71.443396
# Eigen Vector :  [-0.02925981  1.         -0.61655009]
# Error = 1.1021435
#
# Iteration 29
# ----------
# Eigen Value = 70.534906
# Eigen Vector :  [-0.02060267  1.         -0.62975479]
# Error = 0.9084901
#
# Iteration 30
# ----------
# Eigen Value = 71.281713
# Eigen Vector :  [-0.02773524  1.         -0.6188755 ]
# Error = 0.7468068
#
# Iteration 31
# ----------
# Eigen Value = 70.666422
# Eigen Vector :  [-0.02186969  1.         -0.62782222]
# Error = 0.6152906
#
# Iteration 32
# ----------
# Eigen Value = 71.172414
# Eigen Vector :  [-0.02670071  1.         -0.62045348]
# Error = 0.5059916
#
# Iteration 33
# ----------
# Eigen Value = 70.755667
# Eigen Vector :  [-0.02272678  1.         -0.6265149 ]
# Error = 0.4167472
#
# Iteration 34
# ----------
# Eigen Value = 71.098477
# Eigen Vector :  [-0.02599907  1.         -0.62152367]
# Error = 0.3428104
#
# Iteration 35
# ----------
# Eigen Value = 70.816193
# Eigen Vector :  [-0.02330683  1.         -0.62563014]
# Error = 0.2822843
#
# Iteration 36
# ----------
# Eigen Value = 71.048439
# Eigen Vector :  [-0.0255234   1.         -0.62224921]
# Error = 0.2322459
#
# Iteration 37
# ----------
# Eigen Value = 70.857227
# Eigen Vector :  [-0.02369952  1.         -0.62503118]
# Error = 0.191212
#
# Iteration 38
# ----------
# Eigen Value = 71.014564
# Eigen Vector :  [-0.025201    1.         -0.62274097]
# Error = 0.157337
#
# Iteration 39
# ----------
# Eigen Value = 70.885039
# Eigen Vector :  [-0.02396542  1.         -0.62462561]
# Error = 0.129525
#
# Iteration 40
# ----------
# Eigen Value = 70.991626
# Eigen Vector :  [-0.02498252  1.         -0.62307422]
# Error = 0.1065874
#
# Iteration 41
# ----------
# Eigen Value = 70.903886
# Eigen Vector :  [-0.02414549  1.         -0.62435094]
# Error = 0.0877401
#
# Iteration 42
# ----------
# Eigen Value = 70.976092
# Eigen Vector :  [-0.02483448  1.         -0.62330003]
# Error = 0.0722063
#
# Iteration 43
# ----------
# Eigen Value = 70.916657
# Eigen Vector :  [-0.02426745  1.         -0.62416492]
# Error = 0.0594357
#
# Iteration 44
# ----------
# Eigen Value = 70.965572
# Eigen Vector :  [-0.02473418  1.         -0.62345302]
# Error = 0.0489149
#
# Iteration 45
# ----------
# Eigen Value = 70.925309
# Eigen Vector :  [-0.02435005  1.         -0.62403892]
# Error = 0.0402624
#
# Iteration 46
# ----------
# Eigen Value = 70.958445
# Eigen Vector :  [-0.02466622  1.         -0.62355667]
# Error = 0.0331364
#
# Iteration 47
# ----------
# Eigen Value = 70.931171
# Eigen Vector :  [-0.02440601  1.         -0.62395357]
# Error = 0.0272743
#
# Iteration 48
# ----------
# Eigen Value = 70.953619
# Eigen Vector :  [-0.02462019  1.         -0.62362689]
# Error = 0.0224474
#
# Iteration 49
# ----------
# Eigen Value = 70.935143
# Eigen Vector :  [-0.02444391  1.         -0.62389576]
# Error = 0.0184761
#
# Iteration 50
# ----------
# Eigen Value = 70.950349
# Eigen Vector :  [-0.024589    1.         -0.62367446]
# Error = 0.0152064
#
# Iteration 51
# ----------
# Eigen Value = 70.937833
# Eigen Vector :  [-0.02446958  1.         -0.6238566 ]
# Error = 0.012516
#
# Iteration 52
# ----------
# Eigen Value = 70.948134
# Eigen Vector :  [-0.02456787  1.         -0.62370669]
# Error = 0.0103012
#
# Iteration 53
# ----------
# Eigen Value = 70.939656
# Eigen Vector :  [-0.02448698  1.         -0.62383007]
# Error = 0.0084786
#
# Iteration 54
# ----------
# Eigen Value = 70.946634
# Eigen Vector :  [-0.02455356  1.         -0.62372852]
# Error = 0.0069783
#
# Iteration 55
# ----------
# Eigen Value = 70.940890
# Eigen Vector :  [-0.02449876  1.         -0.6238121 ]
# Error = 0.0057436
#
# Iteration 56
# ----------
# Eigen Value = 70.945618
# Eigen Vector :  [-0.02454386  1.         -0.62374331]
# Error = 0.0047272
#
# Iteration 57
# ----------
# Eigen Value = 70.941727
# Eigen Vector :  [-0.02450674  1.         -0.62379993]
# Error = 0.0038908
#
# Iteration 58
# ----------
# Eigen Value = 70.944929
# Eigen Vector :  [-0.02453729  1.         -0.62375333]
# Error = 0.0032023
#
# Iteration 59
# ----------
# Eigen Value = 70.942293
# Eigen Vector :  [-0.02451214  1.         -0.62379168]
# Error = 0.0026357
#
# Iteration 60
# ----------
# Eigen Value = 70.944463
# Eigen Vector :  [-0.02453284  1.         -0.62376011]
# Error = 0.0021693
#
# Iteration 61
# ----------
# Eigen Value = 70.942677
# Eigen Vector :  [-0.02451581  1.         -0.6237861 ]
# Error = 0.0017855
#
# Iteration 62
# ----------
# Eigen Value = 70.944147
# Eigen Vector :  [-0.02452983  1.         -0.62376471]
# Error = 0.0014695
#
# Iteration 63
# ----------
# Eigen Value = 70.942937
# Eigen Vector :  [-0.02451829  1.         -0.62378231]
# Error = 0.0012095
#
# Iteration 64
# ----------
# Eigen Value = 70.943933
# Eigen Vector :  [-0.02452779  1.         -0.62376783]
# Error = 0.0009955
#
# Iteration 65
# ----------
# Eigen Value = 70.943113
# Eigen Vector :  [-0.02451997  1.         -0.62377975]
# Error = 0.0008194
#
# Iteration 66
# ----------
# Eigen Value = 70.943788
# Eigen Vector :  [-0.0245264   1.         -0.62376993]
# Error = 0.0006744
#
# Iteration 67
# ----------
# Eigen Value = 70.943233
# Eigen Vector :  [-0.02452111  1.         -0.62377801]
# Error = 0.000555
#
# Iteration 68
# ----------
# Eigen Value = 70.943690
# Eigen Vector :  [-0.02452547  1.         -0.62377136]
# Error = 0.0004568
#
# Iteration 69
# ----------
# Eigen Value = 70.943314
# Eigen Vector :  [-0.02452188  1.         -0.62377684]
# Error = 0.000376
#
# Iteration 70
# ----------
# Eigen Value = 70.943623
# Eigen Vector :  [-0.02452483  1.         -0.62377233]
# Error = 0.0003095
#
# Iteration 71
# ----------
# Eigen Value = 70.943368
# Eigen Vector :  [-0.0245224   1.         -0.62377604]
# Error = 0.0002547
#
# Iteration 72
# ----------
# Eigen Value = 70.943578
# Eigen Vector :  [-0.0245244   1.         -0.62377299]
# Error = 0.0002096
#
# Iteration 73
# ----------
# Eigen Value = 70.943405
# Eigen Vector :  [-0.02452275  1.         -0.6237755 ]
# Error = 0.0001725
#
# Iteration 74
# ----------
# Eigen Value = 70.943547
# Eigen Vector :  [-0.02452411  1.         -0.62377343]
# Error = 0.000142
#
# Iteration 75
# ----------
# Eigen Value = 70.943431
# Eigen Vector :  [-0.02452299  1.         -0.62377513]
# Error = 0.0001169
#
# Iteration 76
# ----------
# Eigen Value = 70.943527
# Eigen Vector :  [-0.02452391  1.         -0.62377373]
# Error = 9.62e-05
#
# Iteration 77
# ----------
# Eigen Value = 70.943448
# Eigen Vector :  [-0.02452316  1.         -0.62377489]
# Error = 7.92e-05
#
# Iteration 78
# ----------
# Eigen Value = 70.943513
# Eigen Vector :  [-0.02452378  1.         -0.62377394]
# Error = 6.52e-05
#
# Iteration 79
# ----------
# Eigen Value = 70.943459
# Eigen Vector :  [-0.02452327  1.         -0.62377472]
# Error = 5.36e-05
#
# Iteration 80
# ----------
# Eigen Value = 70.943503
# Eigen Vector :  [-0.02452369  1.         -0.62377408]
# Error = 4.41e-05
#
# Iteration 81
# ----------
# Eigen Value = 70.943467
# Eigen Vector :  [-0.02452334  1.         -0.6237746 ]
# Error = 3.63e-05
#
# Iteration 82
# ----------
# Eigen Value = 70.943497
# Eigen Vector :  [-0.02452363  1.         -0.62377417]
# Error = 2.99e-05
#
# Iteration 83
# ----------
# Eigen Value = 70.943472
# Eigen Vector :  [-0.02452339  1.         -0.62377453]
# Error = 2.46e-05
#
# Iteration 84
# ----------
# Eigen Value = 70.943492
# Eigen Vector :  [-0.02452359  1.         -0.62377423]
# Error = 2.03e-05
#
# Iteration 85
# ----------
# Eigen Value = 70.943476
# Eigen Vector :  [-0.02452343  1.         -0.62377448]
# Error = 1.67e-05
#
# Iteration 86
# ----------
# Eigen Value = 70.943490
# Eigen Vector :  [-0.02452356  1.         -0.62377428]
# Error = 1.37e-05
#
# Iteration 87
# ----------
# Eigen Value = 70.943478
# Eigen Vector :  [-0.02452345  1.         -0.62377444]
# Error = 1.13e-05
#
# Iteration 88
# ----------
# Eigen Value = 70.943488
# Eigen Vector :  [-0.02452354  1.         -0.6237743 ]
# Error = 9.3e-06
#
# Iteration 89
# ----------
# Eigen Value = 70.943480
# Eigen Vector :  [-0.02452347  1.         -0.62377442]
# Error = 7.7e-06
#
# Iteration 90
# ----------
# Eigen Value = 70.943486
# Eigen Vector :  [-0.02452353  1.         -0.62377432]
# Error = 6.3e-06
#
# Iteration 91
# ----------
# Eigen Value = 70.943481
# Eigen Vector :  [-0.02452348  1.         -0.6237744 ]
# Error = 5.2e-06
#
# Iteration 92
# ----------
# Eigen Value = 70.943485
# Eigen Vector :  [-0.02452352  1.         -0.62377434]
# Error = 4.3e-06
#
# Iteration 93
# ----------
# Eigen Value = 70.943482
# Eigen Vector :  [-0.02452348  1.         -0.62377439]
# Error = 3.5e-06
#
# Iteration 94
# ----------
# Eigen Value = 70.943485
# Eigen Vector :  [-0.02452351  1.         -0.62377435]
# Error = 2.9e-06
#
# Iteration 95
# ----------
# Eigen Value = 70.943482
# Eigen Vector :  [-0.02452349  1.         -0.62377438]
# Error = 2.4e-06
#
# Iteration 96
# ----------
# Eigen Value = 70.943484
# Eigen Vector :  [-0.02452351  1.         -0.62377435]
# Error = 2e-06
#
# Iteration 97
# ----------
# Eigen Value = 70.943483
# Eigen Vector :  [-0.02452349  1.         -0.62377438]
# Error = 1.6e-06
#
# Iteration 98
# ----------
# Eigen Value = 70.943484
# Eigen Vector :  [-0.0245235   1.         -0.62377436]
# Error = 1.3e-06
#
# Iteration 99
# ----------
# Eigen Value = 70.943483
# Eigen Vector :  [-0.02452349  1.         -0.62377437]
# Error = 1.1e-06
#
# Iteration 100
# ----------
# Eigen Value = 70.943484
# Eigen Vector :  [-0.0245235   1.         -0.62377436]
# Error = 9e-07

# %% [markdown]
# With a tolerable error of $10^{-6}$, the solution converges on the 100th iteration with :
# - Eigen Value = 70.943484
# - Eigen Vector : [-0.024524	, 1.000000	, -0.623774]

# %%
b = a 
pprint(b)

from numpy.linalg import inv

a_inv = inv(b)
pprint(a_inv)
# Out:
# array([[-30.,  10.,  20.],
#        [ 10.,  40., -50.],
#        [ 20., -50., -10.]])
# array([[-0.05576923, -0.01730769, -0.025     ],
#        [-0.01730769, -0.00192308, -0.025     ],
#        [-0.025     , -0.025     , -0.025     ]])

# %%
# Inverse Power Method code to find the smallest eigenvalue

y = np.array([1,1,1], float)

def inv_power(a_inv, x, tolerable_error, max_iteration):
    lambda_old = 1.0
    condition = True
    step = 1
    while condition:
        x = np.dot(a_inv,x)
        lambda_new = min(x)
        x = x/lambda_new
    
        # Displaying Eigen value and Eigen Vector
        print ('\nIteration %d' %(step))
        print ('----------')
        print ('Eigen Value = %0.6f' %(1/lambda_new))
        print ('Eigen Vector : ', x)
    
        # Checking maximum iteration
        step = step + 1
        if step > max_iteration:
            print ('Not convergent in given maximum iteration!')
            break
        
        # Calculating error
        error = abs((1/lambda_new) - (1/lambda_old))
        err2 = np.round(error, 7)
        print ('Error = '+ str(err2))
        lambda_old = lambda_new
        condition = error > tolerable_error

# %%
# Using Inverse Power Method to find the smallest eigenvalue

inv_power(a_inv, y, errmax, itermax)
# Out:
# Iteration 1
# ----------
# Eigen Value = -10.196078
# Eigen Vector :  [1.         0.45098039 0.76470588]
# Error = 11.1960784
#
# Iteration 2
# ----------
# Eigen Value = -12.093023
# Eigen Vector :  [1.         0.45098039 0.66985864]
# Error = 1.8969448
#
# Iteration 3
# ----------
# Eigen Value = -12.450025
# Eigen Vector :  [1.         0.43477264 0.66011245]
# Error = 0.3570013
#
# Iteration 4
# ----------
# Eigen Value = -12.531807
# Eigen Vector :  [1.         0.43418456 0.65631738]
# Error = 0.0817822
#
# Iteration 5
# ----------
# Eigen Value = -12.548327
# Eigen Vector :  [1.         0.43355219 0.65580755]
# Error = 0.0165203
#
# Iteration 6
# ----------
# Eigen Value = -12.552058
# Eigen Vector :  [1.         0.43350587 0.65564414]
# Error = 0.0037314
#
# Iteration 7
# ----------
# Eigen Value = -12.552829
# Eigen Vector :  [1.         0.43348006 0.65561854]
# Error = 0.00077
#
# Iteration 8
# ----------
# Eigen Value = -12.553000
# Eigen Vector :  [1.         0.43347732 0.65561136]
# Error = 0.0001712
#
# Iteration 9
# ----------
# Eigen Value = -12.553036
# Eigen Vector :  [1.         0.43347623 0.65561011]
# Error = 3.58e-05
#
# Iteration 10
# ----------
# Eigen Value = -12.553043
# Eigen Vector :  [1.         0.43347609 0.65560979]
# Error = 7.9e-06
#
# Iteration 11
# ----------
# Eigen Value = -12.553045
# Eigen Vector :  [1.         0.43347604 0.65560973]
# Error = 1.7e-06
#
# Iteration 12
# ----------
# Eigen Value = -12.553045
# Eigen Vector :  [1.         0.43347603 0.65560971]
# Error = 4e-07

# %% [markdown]
# With a tolerable error of $10^{-6}$, the solution converges on the $12^{th}$ iteration with :
# - Eigen Value = -12.553045
# - Eigen Vector :  [1.       ,  0.43347603 , 0.65560971]

# %%
# Problem 2

# creating the matrix

A = 4 * np.eye(10)
A = np.array(A, float)

B = np.array(np.zeros((10, 10)), float)
C = np.array(np.zeros((10, 10)), float)

for i in range(9):
    B[i][i + 1] = 2
    B[i + 1][i] = 2
    
for i in range(8):
    C[i][i + 2] = 1
    C[i + 2][i] = 1

M = A + B + C    

N = M

M_inv = inv(N)

pprint(M)
print("\n")
pprint(M_inv)
# Out:
# array([[4., 2., 1., 0., 0., 0., 0., 0., 0., 0.],
#        [2., 4., 2., 1., 0., 0., 0., 0., 0., 0.],
#        [1., 2., 4., 2., 1., 0., 0., 0., 0., 0.],
#        [0., 1., 2., 4., 2., 1., 0., 0., 0., 0.],
#        [0., 0., 1., 2., 4., 2., 1., 0., 0., 0.],
#        [0., 0., 0., 1., 2., 4., 2., 1., 0., 0.],
#        [0., 0., 0., 0., 1., 2., 4., 2., 1., 0.],
#        [0., 0., 0., 0., 0., 1., 2., 4., 2., 1.],
#        [0., 0., 0., 0., 0., 0., 1., 2., 4., 2.],
#        [0., 0., 0., 0., 0., 0., 0., 1., 2., 4.]])
#
#
# array([[ 0.34601107, -0.17788994, -0.02826441,  0.07606643, -0.02930641,
#         -0.01123413,  0.01582546, -0.00416802, -0.00319114,  0.00263758],
#        [-0.17788994,  0.43744709, -0.16333442, -0.06733963,  0.0910127 ,
#         -0.02344513, -0.01914686,  0.01738847, -0.00231195, -0.00319114],
#        [-0.02826441, -0.16333442,  0.43972647, -0.16958645, -0.06479974,
#          0.09182677, -0.02500814, -0.01810485,  0.01738847, -0.00416802],
#        [ 0.07606643, -0.06733963, -0.16958645,  0.45639857, -0.17583849,
#         -0.06740475,  0.09495278, -0.02500814, -0.01914686,  0.01582546],
#        [-0.02930641,  0.0910127 , -0.06479974, -0.17583849,  0.45815695,
#         -0.17437317, -0.06740475,  0.09182677, -0.02344513, -0.01123413],
#        [-0.01123413, -0.02344513,  0.09182677, -0.06740475, -0.17437317,
#          0.45815695, -0.17583849, -0.06479974,  0.0910127 , -0.02930641],
#        [ 0.01582546, -0.01914686, -0.02500814,  0.09495278, -0.06740475,
#         -0.17583849,  0.45639857, -0.16958645, -0.06733963,  0.07606643],
#        [-0.00416802,  0.01738847, -0.01810485, -0.02500814,  0.09182677,
#         -0.06479974, -0.16958645,  0.43972647, -0.16333442, -0.02826441],
#        [-0.00319114, -0.00231195,  0.01738847, -0.01914686, -0.02344513,
#          0.0910127 , -0.06733963, -0.16333442,  0.43744709, -0.17788994],
#        [ 0.00263758, -0.00319114, -0.00416802,  0.01582546, -0.01123413,
#         -0.02930641,  0.07606643, -0.02826441, -0.17788994,  0.34601107]])

# %%
X = np.zeros(10) + 1
X[-1] += 1
power(M, X, itermax, 0.00001)
# Out:
# Iteration 1
# ----------
# Eigen Value = 11.000000
# Eigen Vector :  [0.63636364 0.81818182 0.90909091 0.90909091 0.90909091 0.90909091
#  0.90909091 1.         1.         1.        ]
# Error = 10.0
#
# Iteration 2
# ----------
# Eigen Value = 9.727273
# Eigen Vector :  [0.52336449 0.74766355 0.88785047 0.92523364 0.93457944 0.94392523
#  0.96261682 1.         0.91588785 0.71962617]
# Error = 1.2727273
#
# Iteration 3
# ----------
# Eigen Value = 9.588785
# Eigen Vector :  [0.4668616  0.70272904 0.87134503 0.94249513 0.97270955 0.99025341
#  1.         0.98245614 0.8411306  0.59551657]
# Error = 0.1384877
#
# Iteration 4
# ----------
# Eigen Value = 9.831384
# Eigen Vector :  [0.42153267 0.65401011 0.83563002 0.93080202 0.97928026 1.
#  0.99266382 0.93556062 0.76494498 0.51333399]
# Error = 0.242599
#
# Iteration 5
# ----------
# Eigen Value = 9.810251
# Eigen Vector :  [0.39038563 0.61784025 0.80660091 0.91812523 0.97928372 1.
#  0.97714136 0.89404382 0.70846639 0.46061886]
# Error = 0.0211332
#
# Iteration 6
# ----------
# Eigen Value = 9.725019
# Eigen Vector :  [0.37057242 0.59469901 0.78848214 0.9112692  0.98067957 1.
#  0.96497528 0.86457512 0.67046986 0.42708934]
# Error = 0.0852316
#
# Iteration 7
# ----------
# Eigen Value = 9.667154
# Eigen Vector :  [0.35793056 0.58012672 0.77759359 0.90803345 0.98257606 1.
#  0.95583465 0.84371058 0.64446927 0.40486292]
# Error = 0.0578652
#
# Iteration 8
# ----------
# Eigen Value = 9.628565
# Eigen Vector :  [0.34995548 0.57117425 0.77137154 0.90694713 0.98454951 1.
#  0.94903079 0.82881641 0.6263507  0.3896843 ]
# Error = 0.0385886
#
# Iteration 9
# ----------
# Eigen Value = 9.602924
# Eigen Vector :  [0.34505552 0.56590035 0.76812373 0.90709921 0.98641773 1.
#  0.9439475  0.81805425 0.61350428 0.37907776]
# Error = 0.0256413
#
# Iteration 10
# ----------
# Eigen Value = 9.585884
# Eigen Vector :  [0.34218509 0.56302154 0.76674904 0.90793715 0.98811342 1.
#  0.94011367 0.81017029 0.60424565 0.37152274]
# Error = 0.0170402
#
# Iteration 11
# ----------
# Eigen Value = 9.574562
# Eigen Vector :  [0.34064562 0.56168541 0.76653244 0.90912727 0.98962136 1.
#  0.93718696 0.80431072 0.59746676 0.36604836]
# Error = 0.0113223
#
# Iteration 12
# ----------
# Eigen Value = 9.567055
# Eigen Vector :  [0.3399673  0.5613248  0.76700953 0.91046852 0.9909486  1.
#  0.93492279 0.79989077 0.59242603 0.36201713]
# Error = 0.007507
#
# Iteration 13
# ----------
# Eigen Value = 9.562102
# Eigen Vector :  [0.3398341  0.56156286 0.76787934 0.91184084 0.9921107  1.
#  0.93314705 0.79650664 0.58861981 0.35900175]
# Error = 0.0049526
#
# Iteration 14
# ----------
# Eigen Value = 9.558863
# Eigen Vector :  [0.34003432 0.56215045 0.7689481  0.91317412 0.99312553 1.
#  0.9317355  0.79387706 0.58570178 0.35671118]
# Error = 0.0032391
#
# Iteration 15
# ----------
# Eigen Value = 9.556773
# Eigen Vector :  [0.34042728 0.56292439 0.77009271 0.91442938 0.99401061 1.
#  0.93059898 0.79180428 0.58343114 0.35494463]
# Error = 0.0020897
#
# Iteration 16
# ----------
# Eigen Value = 9.555453
# Eigen Vector :  [0.34092059 0.56377934 0.77123674 0.91558701 0.99478204 1.
#  0.92967297 0.79014801 0.58163872 0.35356201]
# Error = 0.0013204
#
# Iteration 17
# ----------
# Eigen Value = 9.554645
# Eigen Vector :  [0.34145463 0.56464882 0.77233453 0.91663949 0.99545424 1.
#  0.92891035 0.78880768 0.58020448 0.35246453]
# Error = 0.0008078
#
# Iteration 18
# ----------
# Eigen Value = 9.554176
# Eigen Vector :  [0.34199187 0.56549229 0.77336061 0.91758661 0.9960399  1.
#  0.9282763  0.78771049 0.57904235 0.35158183]
# Error = 0.0004687
#
# Iteration 19
# ----------
# Eigen Value = 9.553929
# Eigen Vector :  [0.34250961 0.56628644 0.77430255 0.91843254 0.99655013 1.
#  0.9277448  0.78680307 0.57808992 0.35086322]
# Error = 0.0002468
#
# Iteration 20
# ----------
# Eigen Value = 9.553825
# Eigen Vector :  [0.34299495 0.56701922 0.77515629 0.91918384 0.99699466 1.
#  0.92729613 0.78604586 0.57730142 0.35027182]
# Error = 0.000104
#
# Iteration 21
# ----------
# Eigen Value = 9.553811
# Eigen Vector :  [0.34344142 0.56768582 0.77592289 0.91984824 0.99738193 1.
#  0.92691514 0.7854091  0.57664287 0.3497804 ]
# Error = 1.42e-05
#
# Iteration 22
# ----------
# Eigen Value = 9.553851
# Eigen Vector :  [0.34384669 0.56828601 0.77660649 0.92043386 0.99771932 1.
#  0.92659003 0.78487015 0.57608868 0.34936868]
# Error = 4.02e-05
#
# Iteration 23
# ----------
# Eigen Value = 9.553923
# Eigen Vector :  [0.344211   0.5688223  0.77721287 0.92094874 0.99801326 1.
#  0.92631149 0.78441148 0.57561931 0.34902127]
# Error = 7.12e-05
#
# Iteration 24
# ----------
# Eigen Value = 9.554010
# Eigen Vector :  [0.34453612 0.56929874 0.77774861 0.92140052 0.99826933 1.
#  0.92607206 0.78401938 0.57521966 0.34872637]
# Error = 8.7e-05
#
# Iteration 25
# ----------
# Eigen Value = 9.554103
# Eigen Vector :  [0.3448247  0.56972016 0.77822048 0.92179632 0.99849241 1.
#  0.9258657  0.78368295 0.57487787 0.34847482]
# Error = 9.3e-05
#
# Iteration 26
# ----------
# Eigen Value = 9.554195
# Eigen Vector :  [0.34507977 0.57009168 0.7786351  0.92214266 0.99868675 1.
#  0.92568746 0.78339341 0.57458451 0.34825936]
# Error = 9.28e-05
#
# Iteration 27
# ----------
# Eigen Value = 9.554284
# Eigen Vector :  [0.34530451 0.57041834 0.77899874 0.92244542 0.99885605 1.
#  0.92553324 0.78314362 0.57433197 0.34807419]
# Error = 8.9e-05
#
# Iteration 28
# ----------
# Eigen Value = 9.554368
# Eigen Vector :  [0.34550204 0.57070499 0.7793172  0.9227099  0.99900354 1.
#  0.92539963 0.7829277  0.57411405 0.34791463]
# Error = 8.31e-05
#
# Iteration 29
# ----------
# Eigen Value = 9.554444
# Eigen Vector :  [0.34567531 0.57095613 0.77959578 0.9229408  0.99913201 1.
#  0.92528373 0.78274077 0.57392566 0.34777684]
# Error = 7.63e-05
#
# Iteration 30
# ----------
# Eigen Value = 9.554513
# Eigen Vector :  [0.34582707 0.57117589 0.77983925 0.92314227 0.99924393 1.
#  0.92518311 0.78257873 0.57376253 0.34765764]
# Error = 6.91e-05
#
# Iteration 31
# ----------
# Eigen Value = 9.554575
# Eigen Vector :  [0.34595985 0.571368   0.78005189 0.92331802 0.99934142 1.
#  0.9250957  0.78243813 0.57362111 0.34755437]
# Error = 6.2e-05
#
# Iteration 32
# ----------
# Eigen Value = 9.554630
# Eigen Vector :  [0.3460759  0.57153582 0.78023749 0.92347127 0.99942634 1.
#  0.92501973 0.78231603 0.57349839 0.34746481]
# Error = 5.53e-05
#
# Iteration 33
# ----------
# Eigen Value = 9.554679
# Eigen Vector :  [0.34617726 0.57168232 0.78039943 0.92360488 0.99950032 1.
#  0.92495366 0.78220993 0.57339181 0.34738707]
# Error = 4.9e-05
#
# Iteration 34
# ----------
# Eigen Value = 9.554723
# Eigen Vector :  [0.34626573 0.57181016 0.78054067 0.92372134 0.99956475 1.
#  0.92489618 0.78211769 0.5732992  0.34731953]
# Error = 4.33e-05
#
# Iteration 35
# ----------
# Eigen Value = 9.554761
# Eigen Vector :  [0.34634293 0.57192167 0.78066382 0.92382284 0.99962088 1.
#  0.92484617 0.78203747 0.57321868 0.34726083]
# Error = 3.82e-05
#
# Iteration 36
# ----------
# Eigen Value = 9.554794
# Eigen Vector :  [0.34641027 0.5720189  0.78077118 0.92391129 0.99966978 1.
#  0.92480265 0.78196768 0.57314865 0.34720979]
# Error = 3.35e-05
#
# Iteration 37
# ----------
# Eigen Value = 9.554824
# Eigen Vector :  [0.34646898 0.57210367 0.78086475 0.92398836 0.99971236 1.
#  0.92476476 0.78190694 0.57308772 0.34716539]
# Error = 2.94e-05
#
# Iteration 38
# ----------
# Eigen Value = 9.554850
# Eigen Vector :  [0.34652016 0.57217756 0.7809463  0.92405551 0.99974946 1.
#  0.92473178 0.78185408 0.57303469 0.34712676]
# Error = 2.57e-05
#
# Iteration 39
# ----------
# Eigen Value = 9.554872
# Eigen Vector :  [0.34656477 0.57224195 0.78101736 0.92411401 0.99978177 1.
#  0.92470306 0.78180806 0.57298854 0.34709313]
# Error = 2.25e-05
#
# Iteration 40
# ----------
# Eigen Value = 9.554892
# Eigen Vector :  [0.34660365 0.57229807 0.78107927 0.92416497 0.99980992 1.
#  0.92467805 0.781768   0.57294837 0.34706387]
# Error = 1.97e-05
#
# Iteration 41
# ----------
# Eigen Value = 9.554909
# Eigen Vector :  [0.34663753 0.57234696 0.78113322 0.92420937 0.99983443 1.
#  0.92465628 0.78173312 0.57291339 0.34703839]
# Error = 1.72e-05
#
# Iteration 42
# ----------
# Eigen Value = 9.554924
# Eigen Vector :  [0.34666705 0.57238956 0.78118021 0.92424805 0.99985579 1.
#  0.92463731 0.78170274 0.57288294 0.34701621]
# Error = 1.5e-05
#
# Iteration 43
# ----------
# Eigen Value = 9.554937
# Eigen Vector :  [0.34669277 0.57242668 0.78122116 0.92428174 0.99987439 1.
#  0.9246208  0.78167629 0.57285641 0.34699689]
# Error = 1.31e-05
#
# Iteration 44
# ----------
# Eigen Value = 9.554948
# Eigen Vector :  [0.34671517 0.57245901 0.78125682 0.92431108 0.99989059 1.
#  0.92460641 0.78165325 0.57283332 0.34698007]
# Error = 1.14e-05
#
# Iteration 45
# ----------
# Eigen Value = 9.554958
# Eigen Vector :  [0.34673469 0.57248717 0.78128789 0.92433665 0.9999047  1.
#  0.92459389 0.78163319 0.57281321 0.34696542]
# Error = 9.9e-06

# %% [markdown]
# We can see that we found the dominant eigenvalue using power method in 62 iterations
# - Eigen Value = 9.555019
# - Eigen Vector :  [0.34685395 0.57265926 0.78147769 0.9244928  0.99999089 1.
#  0.92451739 0.7815107  0.57269042 0.34687601]

# %% [markdown]
# I also noticed that the number of iterations taken for the eigenvalue to dominate are different when we take different initial guess vectors.

# %%
Y = np.zeros(10) + 1
Y[-1] += 1
inv_power(M_inv, Y, errmax, 4000)
# Out:
# Iteration 1
# ----------
# Eigen Value = -11.273862
# Eigen Vector :  [-2.13215859 -0.9695301  -0.8061674  -1.51908957 -0.93979442 -0.73604993
#  -2.19823789 -0.53450808  1.         -6.00330396]
# Error = 12.273862
#
# Iteration 2
# ----------
# Eigen Value = -0.416965
# Eigen Vector :  [ 0.28095966 -0.07109468 -0.0926147   0.3119485  -0.05606527 -0.24593286
#   0.57670546 -0.06259071 -0.71712215  1.        ]
# Error = 10.8568974
#
# Iteration 3
# ----------
# Eigen Value = -1.819542
# Eigen Vector :  [-0.28189822  0.18188096  0.25261309 -0.53959384  0.15538793  0.59288899
#  -0.87874201  0.06223118  1.         -0.97044327]
# Error = 1.4025774
#
# Iteration 4
# ----------
# Eigen Value = -1.364272
# Eigen Vector :  [ 0.28542042 -0.19607299 -0.36494973  0.69521542 -0.16853943 -0.78165744
#   1.         -0.04036889 -0.9885645   0.8353617 ]
# Error = 0.4552696
#
# Iteration 5
# ----------
# Eigen Value = -1.371560
# Eigen Vector :  [-0.3180755   0.19338153  0.49406786 -0.85658504  0.16876138  0.95377082
#  -1.13232307  0.04071486  1.         -0.79661579]
# Error = 0.0072872
#
# Iteration 6
# ----------
# Eigen Value = -1.071647
# Eigen Vector :  [ 0.28143845 -0.14336194 -0.49816516  0.79966437 -0.13084917 -0.87930979
#   1.         -0.04283284 -0.81141456  0.62983829]
# Error = 0.2999122
#
# Iteration 7
# ----------
# Eigen Value = -1.342530
# Eigen Vector :  [-0.31114344  0.12966012  0.60741393 -0.91871373  0.1283967   1.
#  -1.10790431  0.05822886  0.84423266 -0.64806777]
# Error = 0.2708828
#
# Iteration 8
# ----------
# Eigen Value = -1.091713
# Eigen Vector :  [ 0.27833436 -0.09312882 -0.58740045  0.84909582 -0.10378826 -0.91790525
#   1.         -0.06161135 -0.72766494  0.55611132]
# Error = 0.2508171
#
# Iteration 9
# ----------
# Eigen Value = -1.300504
# Eigen Vector :  [-0.29558929  0.07767002  0.66504227 -0.92847166  0.10093993  1.
#  -1.07688167  0.07409427  0.75789453 -0.57827703]
# Error = 0.2087906
#
# Iteration 10
# ----------
# Eigen Value = -1.120227
# Eigen Vector :  [ 0.26997867 -0.05399455 -0.64079845  0.8706097  -0.08501353 -0.93672124
#   1.         -0.07392473 -0.68734255  0.52410285]
# Error = 0.1802766
#
# Iteration 11
# ----------
# Eigen Value = -1.277794
# Eigen Vector :  [-0.28121782  0.04076135  0.69837143 -0.92835869  0.08173529  1.
#  -1.05996543  0.08175586  0.71682056 -0.54627313]
# Error = 0.1575671
#
# Iteration 12
# ----------
# Eigen Value = -1.136817
# Eigen Vector :  [ 0.2607683  -0.02512413 -0.67313163  0.87888497 -0.06968423 -0.94940974
#   1.         -0.0786949  -0.66911937  0.50948661]
# Error = 0.1409768
#
# Iteration 13
# ----------
# Eigen Value = -1.261369
# Eigen Vector :  [-0.26856805  0.01424589  0.71685533 -0.92186729  0.06545709  1.
#  -1.04705154  0.08261245  0.69615494 -0.52939327]
# Error = 0.1245519
#
# Iteration 14
# ----------
# Eigen Value = -1.150397
# Eigen Vector :  [ 0.25254781 -0.00353732 -0.6941568   0.88097882 -0.05547167 -0.96060789
#   1.         -0.07800067 -0.66278651  0.5031465 ]
# Error = 0.1109725
#
# Iteration 15
# ----------
# Eigen Value = -1.246624
# Eigen Vector :  [-0.25762285 -0.00558276  0.72682476 -0.91166305  0.05016802  1.
#  -1.03501843  0.07888078  0.68552005 -0.51928885]
# Error = 0.0962273
#
# Iteration 16
# ----------
# Eigen Value = -1.163666
# Eigen Vector :  [ 0.24554237  0.01344745 -0.70927728  0.88017653 -0.04146276 -0.9718018
#   1.         -0.07371026 -0.66309693  0.50104578]
# Error = 0.0829576
#
# Iteration 17
# ----------
# Eigen Value = -1.232079
# Eigen Vector :  [-0.24798068 -0.02131203  0.73201922 -0.89939729  0.03520794  1.
#  -1.02297102  0.07225985  0.68007762 -0.51243574]
# Error = 0.0684124
#
# Iteration 18
# ----------
# Eigen Value = -1.177375
# Eigen Vector :  [ 0.23947204  0.02771908 -0.72135999  0.87799184 -0.02731524 -0.98340784
#   1.         -0.06710528 -0.66723775  0.50122749]
# Error = 0.0547035
#
# Iteration 19
# ----------
# Eigen Value = -1.217345
# Eigen Vector :  [-0.23921837 -0.03460273  0.73455878 -0.88601358  0.02036012  1.
#  -1.01072     0.0638803   0.67741393 -0.50721878]
# Error = 0.0399701
#
# Iteration 20
# ----------
# Eigen Value = -1.191672
# Eigen Vector :  [ 0.23400415  0.04048584 -0.7319184   0.87512025 -0.01289596 -0.99550042
#   1.         -0.05899877 -0.6736588   0.50268871]
# Error = 0.0256732
#
# Iteration 21
# ----------
# Eigen Value = -1.202385
# Eigen Vector :  [-0.23101298 -0.04646871  0.73562635 -0.87203146  0.00555535  1.
#  -0.99827893  0.05445304  0.67626965 -0.50285438]
# Error = 0.0107125
#
# Iteration 22
# ----------
# Eigen Value = -1.206542
# Eigen Vector :  [ 0.22887805  0.05248592 -0.74175727  0.87188118  0.00185305 -1.00806003
#   1.         -0.0498887  -0.68149058  0.50489614]
# Error = 0.0041569
#
# Iteration 23
# ----------
# Eigen Value = -1.187249
# Eigen Vector :  [-0.22314821 -0.05751013  0.73587793 -0.85773275 -0.00922731  1.
#  -0.98570324  0.04441191  0.67596764 -0.49894613]
# Error = 0.0192927
#
# Iteration 24
# ----------
# Eigen Value = -1.221939
# Eigen Vector :  [ 0.22391572  0.06416005 -0.75130949  0.8684212   0.01696187 -1.02105258
#   1.         -0.04007349 -0.69024059  0.50755909]
# Error = 0.0346901
#
# Iteration 25
# ----------
# Eigen Value = -1.171999
# Eigen Vector :  [-0.21548883 -0.06807522  0.73567673 -0.84327044 -0.0239927   1.
#  -0.97304437  0.03401732  0.67613639 -0.49528723]
# Error = 0.0499398
#
# Iteration 26
# ----------
# Eigen Value = -1.237827
# Eigen Vector :  [ 0.21900295  0.07576865 -0.76081118  0.86480724  0.03244942 -1.03445109
#   1.         -0.02972883 -0.69962889  0.51051664]
# Error = 0.065828
#
# Iteration 27
# ----------
# Eigen Value = -1.156685
# Eigen Vector :  [-0.20795387 -0.07836303  0.73522407 -0.82872876 -0.03873988  1.
#  -0.96034082  0.02342432  0.67656939 -0.49176753]
# Error = 0.081142
#
# Iteration 28
# ----------
# Eigen Value = -1.254183
# Eigen Vector :  [ 0.2140687   0.08746533 -0.77039333  0.86106948  0.04832973 -1.04823883
#   1.         -0.01895625 -0.70949678  0.51367903]
# Error = 0.0974975
#
# Iteration 29
# ----------
# Eigen Value = -1.141343
# Eigen Vector :  [-0.2004965  -0.08848574  0.7346318  -0.81415552 -0.0534655   1.
#  -0.94761955  0.01272516  0.67715084 -0.48832764]
# Error = 0.1128401
#
# Iteration 30
# ----------
# Eigen Value = -1.270993
# Eigen Vector :  [ 0.20906928  0.09934139 -0.78013016  0.857221    0.06461439 -1.06240756
#   1.         -0.00781297 -0.71975514  0.51699611]
# Error = 0.1296509
#
# Iteration 31
# ----------
# Eigen Value = -1.125997
# Eigen Vector :  [-0.19309062 -0.09850553  0.73396224 -0.7995792  -0.06816503  1.
#  -0.93489932  0.00197515  0.67781544 -0.48493547]
# Error = 0.1449969
#
# Iteration 32
# ----------
# Eigen Value = -1.288255
# Eigen Vector :  [ 0.20397778  0.11145195 -0.79006501  0.85326692  0.08131376 -1.07695495
#   1.          0.00367004 -0.73035492  0.52044013]
# Error = 0.1622588
#
# Iteration 33
# ----------
# Eigen Value = -1.110665
# Eigen Vector :  [-0.18572237 -0.10845591  0.7332503  -0.78501801 -0.08283327  1.
#  -0.92219358 -0.0087919   0.6785262  -0.48157381]
# Error = 0.1775901
#
# Iteration 34
# ----------
# Eigen Value = -1.305969
# Eigen Vector :  [ 0.19877733  0.12383137 -0.8002243   0.84920859  0.0984375  -1.09188257
#   1.          0.01547726 -0.74127024  0.52399597]
# Error = 0.1953042
#
# Iteration 35
# ----------
# Eigen Value = -1.095362
# Eigen Vector :  [-0.17838511 -0.11835413  0.73251559 -0.77048461 -0.09746465  1.
#  -0.90951247 -0.01955468  0.67926207 -0.47823366]
# Error = 0.2106076
#
# Iteration 36
# ----------
# Eigen Value = -1.324140
# Eigen Vector :  [ 0.19345698  0.13650202 -0.81062509  0.84504559  0.1159949  -1.10719443
#   1.          0.02760221 -0.75248855  0.52765581]
# Error = 0.2287783
#
# Iteration 37
# ----------
# Eigen Value = -1.080097
# Eigen Vector :  [-0.17107631 -0.12820816  0.73176926 -0.75598868 -0.11205338  1.
#  -0.8968641  -0.03029907  0.68001099 -0.47491058]
# Error = 0.2440432
#
# Iteration 38
# ----------
# Eigen Value = -1.342774
# Eigen Vector :  [ 0.18800927  0.14947947 -0.82127926  0.84077664  0.13399511 -1.12289605
#   1.          0.04004375 -0.76400505  0.53141594]
# Error = 0.2626767
#
# Iteration 39
# ----------
# Eigen Value = -1.064879
# Eigen Vector :  [-0.16379583 -0.13802076  0.73101767 -0.74153824 -0.1265936   1.
#  -0.88425537 -0.04101509  0.68076601 -0.47160268]
# Error = 0.2778944
#
# Iteration 40
# ----------
# Eigen Value = -1.361878
# Eigen Vector :  [ 0.18242873  0.16277537 -0.83219581  0.83640004  0.15244713 -1.13899391
#   1.          0.0528038  -0.77581939  0.53527502]
# Error = 0.2969983
#
# Iteration 41
# ----------
# Eigen Value = -1.049717
# Eigen Vector :  [-0.15654488 -0.14779174  0.73026455 -0.72714037 -0.14107941  1.
#  -0.87169245 -0.05169519  0.68152306 -0.46830949]
# Error = 0.312161
#
# Iteration 42
# ----------
# Eigen Value = -1.381460
# Eigen Vector :  [ 0.17671108  0.17639914 -0.84338211  0.83191388  0.17135999 -1.15549501
#   1.          0.0658861  -0.78793383  0.53923311]
# Error = 0.3317436
#
# Iteration 43
# ----------
# Eigen Value = -1.034616
# Eigen Vector :  [-0.1493254  -0.1575193   0.72951212 -0.71280157 -0.15550492  1.
#  -0.85918103 -0.06233321  0.68227971 -0.46503132]
# Error = 0.3468444
#
# Iteration 44
# ----------
# Eigen Value = -1.401530
# Eigen Vector :  [ 0.1708527   0.19035896 -0.85484467  0.82731614  0.19074266 -1.17240673
#   1.          0.07929545 -0.80035211  0.54329103]
# Error = 0.3669143
#
# Iteration 45
# ----------
# Eigen Value = -1.019583
# Eigen Vector :  [-0.14213972 -0.16720073  0.72876175 -0.69852799 -0.16986434  1.
#  -0.84672648 -0.07292384  0.68303443 -0.4617689 ]
# Error = 0.3819465
#
# Iteration 46
# ----------
# Eigen Value = -1.422096
# Eigen Vector :  [ 0.16485032  0.20466227 -0.86658947  0.82260475  0.21060417 -1.18973664
#   1.          0.09303724 -0.81307882  0.54745005]
# Error = 0.4025128
#
# Iteration 47
# ----------
# Eigen Value = -1.004626
# Eigen Vector :  [-0.13499039 -0.17683287  0.72801437 -0.68432553 -0.18415195  1.
#  -0.83433396 -0.08346225  0.68378626 -0.45852321]
# Error = 0.4174702
#
# Iteration 48
# ----------
# Eigen Value = -1.443168
# Eigen Vector :  [ 0.15870095  0.21931612 -0.87862222  0.81777759  0.23095353 -1.20749245
#   1.          0.10711723 -0.82611908  0.55171173]
# Error = 0.4385419
#
# Iteration 49
# ----------
# Eigen Value = -0.989749
# Eigen Vector :  [-0.12788004 -0.18641231  0.7272706  -0.67019988 -0.19836213  1.
#  -0.82200845 -0.09394399  0.6845345  -0.45529535]
# Error = 0.4534185
#
# Iteration 50
# ----------
# Eigen Value = -1.464754
# Eigen Vector :  [ 0.15240166  0.23432733 -0.89094848  0.81283255  0.25179976 -1.22568194
#   1.          0.12154141 -0.83947829  0.55607774]
# Error = 0.4750049
#
# Iteration 51
# ----------
# Eigen Value = -0.974960
# Eigen Vector :  [-0.1208113  -0.19593558  0.72653092 -0.65615658 -0.21248938  1.
#  -0.80975479 -0.10436481  0.68527866 -0.45208645]
# Error = 0.4897948
#
# Iteration 52
# ----------
# Eigen Value = -1.486865
# Eigen Vector :  [ 0.14594965  0.24970256 -0.90357368  0.80776749  0.27315187 -1.24431292
#   1.          0.13631585 -0.85316201  0.56054987]
# Error = 0.5119051
#
# Iteration 53
# ----------
# Eigen Value = -0.960262
# Eigen Vector :  [-0.11378682 -0.20539918  0.72579573 -0.64220098 -0.22652836  1.
#  -0.79757765 -0.11472065  0.68601833 -0.44889768]
# Error = 0.5266027
#
# Iteration 54
# ----------
# Eigen Value = -1.509508
# Eigen Vector :  [ 0.13934214  0.26544841 -0.91650325  0.80258029  0.29501888 -1.26339322
#   1.          0.1514467  -0.86717588  0.56512994]
# Error = 0.5492462
#
# Iteration 55
# ----------
# Eigen Value = -0.945662
# Eigen Vector :  [-0.10680916 -0.21479965  0.72506536 -0.62833831 -0.24047384  1.
#  -0.78548159 -0.12500759  0.68675316 -0.44573019]
# Error = 0.5638459
#
# Iteration 56
# ----------
# Eigen Value = -1.532694
# Eigen Vector :  [ 0.13257636  0.28157142 -0.92974252  0.7972688   0.31740978 -1.28293067
#   1.          0.16694013 -0.8815256   0.56981979]
# Error = 0.587032
#
# Iteration 57
# ----------
# Eigen Value = -0.931166
# Eigen Vector :  [-0.09988085 -0.22413364  0.7243401  -0.61457361 -0.25432074  1.
#  -0.77347101 -0.13522186  0.68748284 -0.44258511]
# Error = 0.6015285
#
# Iteration 58
# ----------
# Eigen Value = -1.556432
# Eigen Vector :  [ 0.12564961  0.29807807 -0.94329682  0.79183091  0.34033353 -1.30293308
#   1.          0.1828023  -0.89621687  0.57462128]
# Error = 0.6252664
#
# Iteration 59
# ----------
# Eigen Value = -0.916777
# Eigen Vector :  [-0.09300433 -0.23339783  0.72362024 -0.60091177 -0.26806415  1.
#  -0.7615502  -0.14535982  0.6882071  -0.43946356]
# Error = 0.6396546
#
# Iteration 60
# ----------
# Eigen Value = -1.580731
# Eigen Vector :  [ 0.11855916  0.3149748  -0.95717143  0.78626451  0.36379904 -1.32340823
#   1.          0.19903937 -0.91125538  0.57953625]
# Error = 0.6639535
#
# Iteration 61
# ----------
# Eigen Value = -0.902503
# Eigen Vector :  [-0.08618198 -0.24258904  0.72290604 -0.58735754 -0.28169932  1.
#  -0.74972327 -0.15541794  0.68892567 -0.43636659]
# Error = 0.6782283
#
# Iteration 62
# ----------
# Eigen Value = -1.605600
# Eigen Vector :  [ 0.11130235  0.33226799 -0.97137161  0.78056749  0.38781517 -1.34436382
#   1.          0.21565746 -0.92664678  0.58456657]
# Error = 0.7030974
#
# Iteration 63
# ----------
# Eigen Value = -0.888346
# Eigen Vector :  [-0.07941609 -0.25170418  0.72219774 -0.57391547 -0.29522165  1.
#  -0.7379942  -0.16539284  0.6896383  -0.43329526]
# Error = 0.7172542
#
# Iteration 64
# ----------
# Eigen Value = -1.631048
# Eigen Vector :  [ 0.10387651  0.349964   -0.98590254  0.77473777  0.41239072 -1.36580755
#   1.          0.23266265 -0.94239671  0.58971407]
# Error = 0.7427025
#
# Iteration 65
# ----------
# Eigen Value = -0.874312
# Eigen Vector :  [-0.07270887 -0.26074028  0.72149557 -0.56058995 -0.30862673  1.
#  -0.72636684 -0.17528125  0.69034476 -0.43025056]
# Error = 0.7567365
#
# Iteration 66
# ----------
# Eigen Value = -1.657085
# Eigen Vector :  [ 0.096279    0.36806907 -1.00076939  0.76877328  0.43753439 -1.387747
#   1.          0.25006096 -0.95851074  0.59498057]
# Error = 0.7827732
#
# Iteration 67
# ----------
# Eigen Value = -0.860405
# Eigen Vector :  [-0.06606243 -0.26969449  0.72079977 -0.54738519 -0.32191033  1.
#  -0.71484484 -0.18508005  0.69104482 -0.42723346]
# Error = 0.79668
#
# Iteration 68
# ----------
# Eigen Value = -1.683719
# Eigen Vector :  [ 0.08850724  0.38658943 -1.01597724  0.76267198  0.46325478 -1.41018967
#   1.          0.26785834 -0.97499439  0.60036786]
# Error = 0.8233138
#
# Iteration 69
# ----------
# Eigen Value = -0.846630
# Eigen Vector :  [-0.05947881 -0.27856407  0.72011054 -0.53430522 -0.33506839  1.
#  -0.70343174 -0.19478624  0.69173826 -0.42424487]
# Error = 0.8370892
#
# Iteration 70
# ----------
# Eigen Value = -1.710959
# Eigen Vector :  [ 0.08055864  0.40553118 -1.03153111  0.75643185  0.48956039 -1.43314299
#   1.          0.28606066 -0.99185309  0.60587774]
# Error = 0.8643291
#
# Iteration 71
# ----------
# Eigen Value = -0.832990
# Eigen Vector :  [-0.05295994 -0.28734642  0.71942809 -0.5213539  -0.34809703  1.
#  -0.69213089 -0.20439697  0.69242489 -0.42128567]
# Error = 0.877969
#
# Iteration 72
# ----------
# Eigen Value = -1.738813
# Eigen Vector :  [ 0.07243068  0.42490034 -1.04743596  0.75005092  0.51645958 -1.45661424
#   1.          0.30467372 -1.00909221  0.61151195]
# Error = 0.9058235
#
# Iteration 73
# ----------
# Eigen Value = -0.819489
# Eigen Vector :  [-0.04650767 -0.29603905  0.71875261 -0.50853488 -0.36099258  1.
#  -0.68094548 -0.21390953  0.6931045  -0.41835671]
# Error = 0.9193241
#
# Iteration 74
# ----------
# Eigen Value = -1.767291
# Eigen Vector :  [ 0.06412088  0.44470284 -1.06369663  0.74352724  0.54396057 -1.48061061
#   1.          0.32370319 -1.02671701  0.6172722 ]
# Error = 0.9478018
#
# Iteration 75
# ----------
# Eigen Value = -0.806131
# Eigen Vector :  [-0.04012373 -0.3046396   0.71808428 -0.49585165 -0.37375154  1.
#  -0.66987855 -0.22332132  0.69377691 -0.41545876]
# Error = 0.9611594
#
# Iteration 76
# ----------
# Eigen Value = -1.796400
# Eigen Vector :  [ 0.05562681  0.46494447 -1.08031789  0.73685888  0.57207141 -1.5051391
#   1.          0.34315466 -1.04473265  0.6231602 ]
# Error = 0.9902686
#
# Iteration 77
# ----------
# Eigen Value = -0.792920
# Eigen Vector :  [-0.0338098  -0.31314586  0.71742329 -0.48330748 -0.38637061  1.
#  -0.65893297 -0.23262992  0.69444195 -0.4125926 ]
# Error = 1.0034797
#
# Iteration 78
# ----------
# Eigen Value = -1.826149
# Eigen Vector :  [ 0.04694608  0.4856309  -1.0973044   0.730044    0.60079997 -1.5302066
#   1.          0.36303356 -1.06314417  0.62917758]
# Error = 1.0332285
#
# Iteration 79
# ----------
# Eigen Value = -0.779859
# Eigen Vector :  [-0.02756742 -0.32155572  0.71676978 -0.47090546 -0.39884667  1.
#  -0.64811142 -0.24183303  0.69509945 -0.40975891]
# Error = 1.0462899
#
# Iteration 80
# ----------
# Eigen Value = -1.856545
# Eigen Vector :  [ 0.03807638  0.50676766 -1.11466069  0.72308075  0.63015393 -1.5558198
#   1.          0.38334521 -1.0819565   0.63532595]
# Error = 1.0766864
#
# Iteration 81
# ----------
# Eigen Value = -0.766950
# Eigen Vector :  [-0.02139805 -0.32986721  0.71612392 -0.45864851 -0.4111768   1.
#  -0.63741645 -0.2509285   0.69574927 -0.40695837]
# Error = 1.089595
#
# Iteration 82
# ----------
# Eigen Value = -1.887597
# Eigen Vector :  [ 0.02901546  0.52836011 -1.13239116  0.71596739  0.66014073 -1.58198519
#   1.          0.40409476 -1.1011744   0.64160688]
# Error = 1.1206468
#
# Iteration 83
# ----------
# Eigen Value = -0.754197
# Eigen Vector :  [-0.01530305 -0.33807851  0.71548584 -0.44653932 -0.42335829  1.
#  -0.62685041 -0.25991432  0.69639125 -0.40419159]
# Error = 1.1333998
#
# Iteration 84
# ----------
# Eigen Value = -1.919312
# Eigen Vector :  [ 0.01976113  0.55041344 -1.15050009  0.70870219  0.6907676  -1.60870909
#   1.          0.42528721 -1.12080251  0.64802187]
# Error = 1.1651144
#
# Iteration 85
# ----------
# Eigen Value = -0.741603
# Eigen Vector :  [-0.0092837  -0.34618789  0.71485568 -0.43458041 -0.4353886   1.
#  -0.6164155  -0.26878862  0.69702526 -0.40145915]
# Error = 1.1777092
#
# Iteration 86
# ----------
# Eigen Value = -1.951696
# Eigen Vector :  [ 0.0103113   0.57293268 -1.16899159  0.70128351  0.7220415  -1.63599755
#   1.          0.44692737 -1.14084528  0.65457238]
# Error = 1.2100938
#
# Iteration 87
# ----------
# Eigen Value = -0.729169
# Eigen Vector :  [-0.00334116 -0.35419379  0.71423356 -0.42277411 -0.44726538  1.
#  -0.60611375 -0.27754967  0.69765118 -0.39876157]
# Error = 1.2225278
#
# Iteration 88
# ----------
# Eigen Value = -1.984758
# Eigen Vector :  [ 6.63943485e-04  5.95922618e-01 -1.18786961e+00  6.93709762e-01
#   7.53969091e-01 -1.66385641e+00  1.00000000e+00  4.69019864e-01
#  -1.16130700e+00  6.61259821e-01]
# Error = 1.2555893
#
# Iteration 89
# ----------
# Eigen Value = -0.716897
# Eigen Vector :  [ 0.00252349 -0.36209476  0.7136196  -0.41112256 -0.4589865   1.
#  -0.59594703 -0.28619589  0.6982689  -0.39609936]
# Error = 1.2678603
#
# Iteration 90
# ----------
# Eigen Value = -2.018503
# Eigen Vector :  [-0.00918287  0.61938787 -1.20713792  0.68597943  0.78655677 -1.69229123
#   1.          0.49156911 -1.18219175  0.66808552]
# Error = 1.3016053
#
# Iteration 91
# ----------
# Eigen Value = -0.704791
# Eigen Vector :  [ 0.00830927 -0.36988948  0.7130139  -0.39962769 -0.47055     1.
#  -0.58591703 -0.29472583  0.69887831 -0.39347294]
# Error = 1.3137114
#
# Iteration 92
# ----------
# Eigen Value = -2.052938
# Eigen Vector :  [-0.01923097  0.64333278 -1.22680011  0.67809107  0.8198106  -1.72130731
#   1.          0.5145793  -1.20350342  0.67505074]
# Error = 1.3481462
#
# Iteration 93
# ----------
# Eigen Value = -0.692852
# Eigen Vector :  [ 0.01401529 -0.37757675  0.71241654 -0.38829128 -0.48195409  1.
#  -0.57602529 -0.3031382   0.69947932 -0.39088273]
# Error = 1.3600854
#
# Iteration 94
# ----------
# Eigen Value = -2.088068
# Eigen Vector :  [-0.02948208  0.66776149 -1.24685956  0.67004334  0.8537363  -1.75090964
#   1.          0.53805439 -1.22524568  0.6821567 ]
# Error = 1.3952159
#
# Iteration 95
# ----------
# Eigen Value = -0.681082
# Eigen Vector :  [ 0.01964077 -0.3851555   0.71182761 -0.37711489 -0.49319721  1.
#  -0.56627318 -0.31143181  0.70007185 -0.38832908]
# Error = 1.4069865
#
# Iteration 96
# ----------
# Eigen Value = -2.123900
# Eigen Vector :  [-0.03993782  0.69267784 -1.26731943  0.66183496  0.88833923 -1.7811029
#   1.          0.5619981  -1.24742196  0.6894045 ]
# Error = 1.4428184
#
# Iteration 97
# ----------
# Eigen Value = -0.669481
# Eigen Vector :  [ 0.025185   -0.3926248   0.7112472  -0.36609993 -0.50427793  1.
#  -0.55666192 -0.31960564  0.70065581 -0.38581232]
# Error = 1.454419
#
# Iteration 98
# ----------
# Eigen Value = -2.160438
# Eigen Vector :  [-0.0505997   0.71808542 -1.28818268  0.65346474  0.92362435 -1.81189142
#   1.          0.58641385 -1.27003545  0.69679519]
# Error = 1.4909573
#
# Iteration 99
# ----------
# Eigen Value = -0.658052
# Eigen Vector :  [ 0.03064737 -0.3999838   0.71067535 -0.35524761 -0.51519505  1.
#  -0.54719258 -0.32765878  0.70123116 -0.38333271]
# Error = 1.5023866
#
# Iteration 100
# ----------
# Eigen Value = -2.197688
# Eigen Vector :  [-0.0614691   0.74398752 -1.30945199  0.64493162  0.95959625 -1.84327918
#   1.          0.61130482 -1.29308907  0.70432974]
# Error = 1.539636
#
# Iteration 101
# ----------
# Eigen Value = -0.646795
# Eigen Vector :  [ 0.03602735 -0.40723182  0.71011212 -0.34455896 -0.52594751  1.
#  -0.53786606 -0.33559046  0.70179783 -0.38089051]
# Error = 1.550893
#
# Iteration 102
# ----------
# Eigen Value = -2.235653
# Eigen Vector :  [-0.07254727  0.77038712 -1.33112982  0.6362346   0.99625905 -1.87526981
#   1.          0.63667387 -1.31658548  0.71200899]
# Error = 1.5888578
#
# Iteration 103
# ----------
# Eigen Value = -0.635711
# Eigen Vector :  [ 0.04132451 -0.41436825  0.70955757 -0.33403487 -0.53653443  1.
#  -0.52868312 -0.34340003  0.70235577 -0.3784859 ]
# Error = 1.5999415
#
# Iteration 104
# ----------
# Eigen Value = -2.200368
# Eigen Vector :  [-0.08110872  0.77135661 -1.30920746  0.60696869  1.         -1.84581673
#   0.96747688  0.6409762  -1.29692891  0.69642249]
# Error = 1.5646571
#
# Iteration 105
# ----------
# Eigen Value = -0.645805
# Eigen Vector :  [ 0.04653849 -0.42139263  0.70901173 -0.32367603 -0.54695512  1.
#  -0.51964437 -0.35108697  0.70290496 -0.37611905]
# Error = 1.5545631
#
# Iteration 106
# ----------
# Eigen Value = -2.159004
# Eigen Vector :  [-0.08895841  0.76953523 -1.28371363  0.57699158  1.         -1.8112564
#   0.93312166  0.64278651 -1.27363249  0.67913027]
# Error = 1.513199
#
# Iteration 107
# ----------
# Eigen Value = -0.658078
# Eigen Vector :  [ 0.05166902 -0.42830457  0.70847462 -0.31348298 -0.55720903  1.
#  -0.51075029 -0.35865088  0.70344535 -0.37379008]
# Error = 1.5009265
#
# Iteration 108
# ----------
# Eigen Value = -2.119793
# Eigen Vector :  [-0.09639961  0.76780864 -1.25954644  0.54857441  1.         -1.77849452
#   0.90055422  0.6445026  -1.25154837  0.6627379 ]
# Error = 1.4617149
#
# Iteration 109
# ----------
# Eigen Value = -0.670150
# Eigen Vector :  [ 0.05671591 -0.43510384  0.70794627 -0.3034561  -0.56729577  1.
#  -0.5020012  -0.36609149  0.70397693 -0.37149908]
# Error = 1.4496424
#
# Iteration 110
# ----------
# Eigen Value = -2.082586
# Eigen Vector :  [-0.10346042  0.76617031 -1.2366147   0.52160996  1.         -1.74740745
#   0.86965165  0.64613097 -1.2305932   0.64718351]
# Error = 1.4124353
#
# Iteration 111
# ----------
# Eigen Value = -0.682022
# Eigen Vector :  [ 0.06167905 -0.44179028  0.70742668 -0.29359562 -0.57721512  1.
#  -0.4933973  -0.37340861  0.7044997  -0.3692461 ]
# Error = 1.4005632
#
# Iteration 112
# ----------
# Eigen Value = -2.047248
# Eigen Vector :  [-0.11016642  0.76461431 -1.21483527  0.49600045  1.         -1.71788249
#   0.84030192  0.64767751 -1.21069103  0.63241074]
# Error = 1.3652258
#
# Iteration 113
# ----------
# Eigen Value = -0.693694
# Eigen Vector :  [ 0.06655839 -0.44836382  0.70691587 -0.28390162 -0.586967    1.
#  -0.48493867 -0.3806022   0.70501363 -0.36703116]
# Error = 1.3535541
#
# Iteration 114
# ----------
# Eigen Value = -2.013657
# Eigen Vector :  [-0.116541    0.76313521 -1.19413221  0.47165661  1.         -1.68981671
#   0.81240271  0.64914762 -1.19177245  0.61836805]
# Error = 1.3199631
#
# Iteration 115
# ----------
# Eigen Value = -0.705165
# Eigen Vector :  [ 0.07135398 -0.45482453  0.70641383 -0.27437401 -0.59655149  1.
#  -0.47662523 -0.38767231  0.70551875 -0.36485423]
# Error = 1.3084918
#
# Iteration 116
# ----------
# Eigen Value = -1.981700
# Eigen Vector :  [-0.12260556  0.76172804 -1.17443602  0.4484967   1.         -1.66311586
#   0.78586034  0.65054624 -1.17377396  0.60500831]
# Error = 1.2765345
#
# Iteration 117
# ----------
# Eigen Value = -0.716437
# Eigen Vector :  [ 0.07606591 -0.46117254  0.70592054 -0.26501261 -0.60596879  1.
#  -0.4684568  -0.39461909  0.70601505 -0.36271528]
# Error = 1.2652632
#
# Iteration 118
# ----------
# Eigen Value = -1.951273
# Eigen Vector :  [-0.12837972  0.76038825 -1.15568296  0.42644578  1.         -1.63769356
#   0.76058891  0.65187788 -1.1566373   0.59228829]
# Error = 1.2348361
#
# Iteration 119
# ----------
# Eigen Value = -0.727508
# Eigen Vector :  [ 0.08069437 -0.46740809  0.70543599 -0.25581705 -0.61521925  1.
#  -0.46043309 -0.4014428   0.70650256 -0.36061423]
# Error = 1.2237646
#
# Iteration 120
# ----------
# Eigen Value = -1.922281
# Eigen Vector :  [-0.13388153  0.75911166 -1.13781447  0.40543497  1.         -1.6134704
#   0.73650952  0.65314671 -1.14030896  0.58016826]
# Error = 1.1947727
#
# Iteration 121
# ----------
# Eigen Value = -0.738381
# Eigen Vector :  [ 0.08523959 -0.47353149  0.70496016 -0.24678687 -0.62430334  1.
#  -0.45255369 -0.40814379  0.70698131 -0.35855096]
# Error = 1.1839003
#
# Iteration 122
# ----------
# Eigen Value = -1.894637
# Eigen Vector :  [-0.13912756  0.75789442 -1.12077663  0.38540091  1.         -1.59037332
#   0.71354952  0.65435656 -1.12473968  0.56861166]
# Error = 1.1562561
#
# Iteration 123
# ----------
# Eigen Value = -0.749055
# Eigen Vector :  [ 0.08970187 -0.47954316  0.70449301 -0.23792147 -0.63322167  1.
#  -0.44481806 -0.4147225   0.70745131 -0.35652534]
# Error = 1.1455821
#
# Iteration 124
# ----------
# Eigen Value = -1.868260
# Eigen Vector :  [-0.14413314  0.75673296 -1.10451977  0.36628516  1.         -1.56833495
#   0.69164194  0.65551095 -1.10988406  0.55758478]
# Error = 1.1192051
#
# Iteration 125
# ----------
# Eigen Value = -0.759531
# Eigen Vector :  [ 0.09408156 -0.48544357  0.7040345  -0.22922013 -0.64197496  1.
#  -0.43722559 -0.42117947  0.70791262 -0.3545372 ]
# Error = 1.1087286
#
# Iteration 126
# ----------
# Eigen Value = -1.843075
# Eigen Vector :  [-0.14891238  0.75562403 -1.08899798  0.34803375  1.         -1.54729307
#   0.67072495  0.65661314 -1.09570016  0.5470565 ]
# Error = 1.0835443
#
# Iteration 127
# ----------
# Eigen Value = -0.769811
# Eigen Vector :  [ 0.0983791  -0.4912333   0.7035846  -0.22068202 -0.65056405  1.
#  -0.42977554 -0.42751531  0.70836528 -0.35258636]
# Error = 1.0732643
#
# Iteration 128
# ----------
# Eigen Value = -1.819015
# Eigen Vector :  [-0.15347835  0.75456458 -1.07416883  0.33059678  1.         -1.52719016
#   0.65074134  0.65766615 -1.08214919  0.53699803]
# Error = 1.0492038
#
# Iteration 129
# ----------
# Eigen Value = -0.779896
# Eigen Vector :  [ 0.10259496 -0.49691298  0.70314325 -0.2123062  -0.65898987  1.
#  -0.42246711 -0.43373072  0.70880933 -0.35067261]
# Error = 1.0391193
#
# Iteration 130
# ----------
# Eigen Value = -1.796015
# Eigen Vector :  [-0.15784316  0.75355181 -1.059993    0.31392803  1.         -1.5079729
#   0.63163814  0.65867276 -1.06919523  0.5273827 ]
# Error = 1.0161188
#
# Iteration 131
# ----------
# Eigen Value = -0.789786
# Eigen Vector :  [ 0.10672965 -0.50248332  0.70271039 -0.20409163 -0.66725349  1.
#  -0.41529937 -0.43982647  0.70924483 -0.34879569]
# Error = 1.0062283
#
# Iteration 132
# ----------
# Eigen Value = -1.774015
# Eigen Vector :  [-0.16201804  0.75258311 -1.04643402  0.2979846   1.         -1.48959187
#   0.6133662   0.65963558 -1.05680495  0.51818577]
# Error = 0.9842287
#
# Iteration 133
# ----------
# Eigen Value = -0.799484
# Eigen Vector :  [ 0.11078375 -0.50794508  0.70228597 -0.19603716 -0.67535604  1.
#  -0.40827134 -0.44580341  0.70967185 -0.34695536]
# Error = 0.974531
#
# Iteration 134
# ----------
# Eigen Value = -1.752961
# Eigen Vector :  [-0.16601343  0.75165605 -1.033458    0.28272666  1.         -1.47200114
#   0.59587987  0.660557   -1.04494739  0.50938426]
# Error = 0.9534773
#
# Iteration 135
# ----------
# Eigen Value = -0.808990
# Eigen Vector :  [ 0.11475789 -0.51329911  0.70186993 -0.18814158 -0.68329877  1.
#  -0.40138194 -0.45166246  0.71009044 -0.34515133]
# Error = 0.9439709
#
# Iteration 136
# ----------
# Eigen Value = -1.732802
# Eigen Vector :  [-0.16983901  0.7507684  -1.02103345  0.26811715  1.         -1.45515797
#   0.57913667  0.66143926 -1.03359376  0.50095681]
# Error = 0.9238119
#
# Iteration 137
# ----------
# Eigen Value = -0.818307
# Eigen Vector :  [ 0.11865272 -0.51854631  0.70146218 -0.18040354 -0.691083    1.
#  -0.39463001 -0.45740459  0.71050068 -0.3433833 ]
# Error = 0.9144952
#
# Iteration 138
# ----------
# Eigen Value = -1.713490
# Eigen Vector :  [-0.17350384  0.74991804 -1.009131    0.25412157  1.         -1.4390226
#   0.56309705  0.66228444 -1.02271723  0.49288349]
# Error = 0.8951833
#
# Iteration 139
# ----------
# Eigen Value = -0.827436
# Eigen Vector :  [ 0.12246895 -0.52368761  0.70106266 -0.17282166 -0.69871015  1.
#  -0.38801434 -0.46303085  0.71090264 -0.34165094]
# Error = 0.8860547
#
# Iteration 140
# ----------
# Eigen Value = -1.694981
# Eigen Vector :  [-0.17701634  0.74910303 -0.99772328  0.24070772  1.         -1.4235579
#   0.54772414  0.6630945  -1.01229279  0.48514574]
# Error = 0.8675455
#
# Iteration 141
# ----------
# Eigen Value = -0.836378
# Eigen Vector :  [ 0.12620734 -0.52872404  0.7006713  -0.16539445 -0.70618171  1.
#  -0.38153362 -0.46854233  0.7112964  -0.33995393]
# Error = 0.8586031
#
# Iteration 142
# ----------
# Eigen Value = -1.677233
# Eigen Vector :  [-0.18038437  0.74832154 -0.98678475  0.22784556  1.         -1.40872924
#   0.53298349  0.66387124 -1.00229709  0.47772624]
# Error = 0.8408551
#
# Iteration 143
# ----------
# Eigen Value = -0.845136
# Eigen Vector :  [ 0.12986865 -0.53365663  0.700288   -0.15812036 -0.71349923  1.
#  -0.37518651 -0.47394018  0.71168204 -0.3382919 ]
# Error = 0.832097
#
# Iteration 144
# ----------
# Eigen Value = -1.660208
# Eigen Vector :  [-0.18361529  0.74757187 -0.9762915   0.215507    1.         -1.39450423
#   0.5188429   0.66461635 -0.9927083   0.47060877]
# Error = 0.8150716
#
# Iteration 145
# ----------
# Eigen Value = -0.853712
# Eigen Vector :  [ 0.13345371 -0.53848649  0.69991268 -0.15099777 -0.72066434  1.
#  -0.3689716  -0.47922561  0.71205965 -0.33666449]
# Error = 0.8064959
#
# Iteration 146
# ----------
# Eigen Value = -1.643869
# Eigen Vector :  [-0.18671599  0.74685241 -0.9662212   0.20366576  1.         -1.38085257
#   0.50527227  0.66533144 -0.983506    0.46377818]
# Error = 0.7901567
#
# Iteration 147
# ----------
# Eigen Value = -0.862107
# Eigen Vector :  [ 0.13696336 -0.54321475  0.69954526 -0.144025   -0.72767874  1.
#  -0.36288742 -0.48439987  0.71242932 -0.33507131]
# Error = 0.7817614
#
# Iteration 148
# ----------
# Eigen Value = -1.628182
# Eigen Vector :  [-0.18969291  0.74616167 -0.95655289  0.19229721  1.         -1.36774588
#   0.49224336  0.66601798 -0.97467104  0.45722026]
# Error = 0.7660745
#
# Iteration 149
# ----------
# Eigen Value = -0.870324
# Eigen Vector :  [ 0.14039847 -0.5478426   0.69918565 -0.13720031 -0.73454417  1.
#  -0.35693244 -0.48946423  0.71279114 -0.33351196]
# Error = 0.7578575
#
# Iteration 150
# ----------
# Eigen Value = -1.613115
# Eigen Vector :  [-0.19255211  0.74549825 -0.94726695  0.18137827  1.         -1.35515753
#   0.47972972  0.66667737 -0.96618548  0.45092169]
# Error = 0.7427909
#
# Iteration 151
# ----------
# Eigen Value = -0.878365
# Eigen Vector :  [ 0.14375995 -0.55237126  0.69883374 -0.13052191 -0.74126245  1.
#  -0.35110511 -0.49442005  0.7131452  -0.33198604]
# Error = 0.73475
#
# Iteration 152
# ----------
# Eigen Value = -1.598639
# Eigen Vector :  [-0.19529924  0.74486082 -0.93834493  0.17088724  1.         -1.34306252
#   0.4677065   0.66731092 -0.95803249  0.44486997]
# Error = 0.7202739
#
# Iteration 153
# ----------
# Eigen Value = -0.886232
# Eigen Vector :  [ 0.14704873 -0.55680196  0.69848944 -0.12398796 -0.74783541  1.
#  -0.34540382 -0.49926867  0.7134916  -0.33049313]
# Error = 0.712407
#
# Iteration 154
# ----------
# Eigen Value = -1.584725
# Eigen Vector :  [-0.19793966  0.74424816 -0.9297695   0.16080377  1.         -1.33143738
#   0.45615036  0.66791985 -0.95019622  0.43905334]
# Error = 0.6984933
#
# Iteration 155
# ----------
# Eigen Value = -0.893927
# Eigen Vector :  [ 0.15026574 -0.56113598  0.69815265 -0.11759657 -0.75426496  1.
#  -0.33982693 -0.5040115   0.71383045 -0.32903278]
# Error = 0.690798
#
# Iteration 156
# ----------
# Eigen Value = -1.571347
# Eigen Vector :  [-0.20047837  0.7436591  -0.92152439  0.15110869  1.         -1.32026002
#   0.44503933  0.66850533 -0.94266178  0.43346076]
# Error = 0.6774202
#
# Iteration 157
# ----------
# Eigen Value = -0.901453
# Eigen Vector :  [ 0.15341197 -0.56537464  0.69782328 -0.11134582 -0.76055303  1.
#  -0.33437275 -0.50864997  0.71416184 -0.32760458]
# Error = 0.6698942
#
# Iteration 158
# ----------
# Eigen Value = -1.558481
# Eigen Vector :  [-0.20292011  0.74309254 -0.91359425  0.14178398  1.         -1.30950964
#   0.43435276  0.66906845 -0.93541517  0.42808182]
# Error = 0.6570274
#
# Iteration 159
# ----------
# Eigen Value = -0.908812
# Eigen Vector :  [ 0.1564884  -0.56951927  0.69750121 -0.10523375 -0.76670159  1.
#  -0.32903958 -0.51318553  0.71448587 -0.32620805]
# Error = 0.6496684
#
# Iteration 160
# ----------
# Eigen Value = -1.546101
# Eigen Vector :  [-0.20526931  0.74254746 -0.90596463  0.13281263  1.         -1.29916666
#   0.42407116  0.66961022 -0.92844318  0.42290672]
# Error = 0.6372892
#
# Iteration 161
# ----------
# Eigen Value = -0.916007
# Eigen Vector :  [ 0.15949603 -0.5735712   0.69718635 -0.09925836 -0.77271266  1.
#  -0.32382567 -0.51761966  0.71480266 -0.32484276]
# Error = 0.6300948
#
# Iteration 162
# ----------
# Eigen Value = -1.534188
# Eigen Vector :  [-0.20753017  0.74202286 -0.8986219   0.12417862  1.         -1.2892126
#   0.41417617  0.67013162 -0.92173334  0.41792622]
# Error = 0.6181811
#
# Iteration 163
# ----------
# Eigen Value = -0.923039
# Eigen Vector :  [ 0.16243588 -0.57753182  0.69687858 -0.09341764 -0.77858825  1.
#  -0.31872927 -0.52195386  0.71511232 -0.32350824]
# Error = 0.6111488
#
# Iteration 164
# ----------
# Eigen Value = -1.522719
# Eigen Vector :  [-0.20970666  0.74151785 -0.89155319  0.11586683  1.         -1.27963001
#   0.40465046  0.67063357 -0.91527392  0.41313158]
# Error = 0.5996798
#
# Iteration 165
# ----------
# Eigen Value = -0.929912
# Eigen Vector :  [ 0.16530897 -0.58140251  0.6965778  -0.08770953 -0.78433043  1.
#  -0.31374859 -0.52618965  0.71541494 -0.32220402]
# Error = 0.5928071
#
# Iteration 166
# ----------
# Eigen Value = -1.511675
# Eigen Vector :  [-0.21180252  0.74103154 -0.88474636  0.10786297  1.         -1.27040243
#   0.39547764  0.67111692 -0.90905379  0.40851457]
# Error = 0.581763
#
# Iteration 167
# ----------
# Eigen Value = -0.936627
# Eigen Vector :  [ 0.16811635 -0.58518467  0.6962839  -0.08213198 -0.78994129  1.
#  -0.30888182 -0.53032856  0.71571063 -0.32092962]
# Error = 0.5750475
#
# Iteration 168
# ----------
# Eigen Value = -1.501037
# Eigen Vector :  [-0.21382129  0.74056313 -0.87818991  0.10015352  1.         -1.26151429
#   0.38664225  0.67158248 -0.90306247  0.4040674 ]
# Error = 0.5644096
#
# Iteration 169
# ----------
# Eigen Value = -0.943188
# Eigen Vector :  [ 0.17085908 -0.58887972  0.69599676 -0.0766829  -0.7954229   1.
#  -0.30412715 -0.53437214  0.71599952 -0.31968458]
# Error = 0.5578489
#
# Iteration 170
# ----------
# Eigen Value = -1.490787
# Eigen Vector :  [-0.2157663   0.74011182 -0.87187299  0.09272572  1.         -1.25295085
#   0.37812963  0.67203105 -0.89729003  0.39978269]
# Error = 0.5475996
#
# Iteration 171
# ----------
# Eigen Value = -0.949596
# Eigen Vector :  [ 0.17353819 -0.59248907  0.69571629 -0.07136018 -0.80077739  1.
#  -0.29948274 -0.53832194  0.71628171 -0.31846842]
# Error = 0.541191
#
# Iteration 172
# ----------
# Eigen Value = -1.480910
# Eigen Vector :  [-0.21764073  0.7396769  -0.8657853   0.08556747  1.         -1.24469816
#   0.36992593  0.67246333 -0.89172707  0.39565347]
# Error = 0.5313136
#
# Iteration 173
# ----------
# Eigen Value = -0.955855
# Eigen Vector :  [ 0.17615476 -0.59601417  0.69544237 -0.06616173 -0.80600688  1.
#  -0.29494676 -0.54217954  0.71655731 -0.31728065]
# Error = 0.5250546
#
# Iteration 174
# ----------
# Eigen Value = -1.471389
# Eigen Vector :  [-0.21944758  0.73925765 -0.8599171   0.0786673   1.         -1.23674302
#   0.362018    0.67288003 -0.88636466  0.39167312]
# Error = 0.5155334
#
# Iteration 175
# ----------
# Eigen Value = -0.961967
# Eigen Vector :  [ 0.17870985 -0.59945643  0.69517488 -0.06108542 -0.8111135   1.
#  -0.29051736 -0.54594649  0.71682644 -0.31612078]
# Error = 0.5094214
#
# Iteration 176
# ----------
# Eigen Value = -1.462209
# Eigen Vector :  [-0.2211897   0.73885343 -0.85425914  0.07201434  1.         -1.22907289
#   0.35439339  0.67328179 -0.88119439  0.38783538]
# Error = 0.5002413
#
# Iteration 177
# ----------
# Eigen Value = -0.967935
# Eigen Vector :  [ 0.18120453 -0.60281731  0.69491371 -0.05612914 -0.81609938  1.
#  -0.28619268 -0.54962438  0.7170892  -0.31498834]
# Error = 0.4942739
#
# Iteration 178
# ----------
# Eigen Value = -1.453355
# Eigen Vector :  [-0.22286978  0.73846359 -0.84880265  0.0655983   1.         -1.22167589
#   0.3470403   0.67366926 -0.87620822  0.3841343 ]
# Error = 0.4854207
#
# Iteration 179
# ----------
# Eigen Value = -0.973760
# Eigen Vector :  [ 0.18363986 -0.60609825  0.69465876 -0.05129074 -0.82096666  1.
#  -0.28197088 -0.55321479  0.71734571 -0.31388283]
# Error = 0.4795952
#
# Iteration 180
# ----------
# Eigen Value = -1.444816
# Eigen Vector :  [-0.22449039  0.73808756 -0.84353933  0.05940937  1.         -1.21454074
#   0.33994749  0.674043   -0.87139856  0.38056423]
# Error = 0.4710554
#
# Iteration 181
# ----------
# Eigen Value = -0.979446
# Eigen Vector :  [ 0.18601693 -0.60930068  0.69440991 -0.04656812 -0.82571748  1.
#  -0.27785009 -0.55671929  0.71759609 -0.31280378]
# Error = 0.4653693
#
# Iteration 182
# ----------
# Eigen Value = -1.436576
# Eigen Vector :  [-0.22605395  0.73772477 -0.83846124  0.05343827  1.         -1.20765671
#   0.33310432  0.67440359 -0.86675818  0.37711982]
# Error = 0.45713
#
# Iteration 183
# ----------
# Eigen Value = -0.984996
# Eigen Vector :  [ 0.1883368  -0.61242605  0.69416704 -0.04195914 -0.83035397  1.
#  -0.27382846 -0.56013946  0.71784043 -0.31175069]
# Error = 0.4515808
#
# Iteration 184
# ----------
# Eigen Value = -1.428625
# Eigen Vector :  [-0.2275628   0.73737467 -0.83356089  0.04767616  1.         -1.20101363
#   0.32650066  0.67475156 -0.86228021  0.37379596]
# Error = 0.4436299
#
# Iteration 185
# ----------
# Eigen Value = -0.990411
# Eigen Vector :  [ 0.19060053 -0.61547579  0.69393006 -0.03746168 -0.83487828  1.
#  -0.26990414 -0.56347686  0.71807887 -0.31072309]
# Error = 0.4382149
#
# Iteration 186
# ----------
# Eigen Value = -1.420951
# Eigen Vector :  [-0.22901912  0.73703676 -0.82883113  0.04211463  1.         -1.19460179
#   0.32012688  0.67508742 -0.85795812  0.3705878 ]
# Error = 0.4305408
#
# Iteration 187
# ----------
# Eigen Value = -0.995694
# Eigen Vector :  [ 0.19280919 -0.61845134  0.69369883 -0.03307364 -0.83929252  1.
#  -0.26607529 -0.56673308  0.71831151 -0.30972048]
# Error = 0.4252575
#
# Iteration 188
# ----------
# Eigen Value = -1.413543
# Eigen Vector :  [-0.23042501  0.73671054 -0.82426514  0.03674568  1.         -1.18841199
#   0.31397381  0.67541165 -0.85378569  0.36749074]
# Error = 0.4178492
#
# Iteration 189
# ----------
# Eigen Value = -1.000848
# Eigen Vector :  [ 0.19496384 -0.62135413  0.69347327 -0.0287929  -0.84359882  1.
#  -0.26234008 -0.56990967  0.71853845 -0.30874239]
# Error = 0.4126951
#
# Iteration 190
# ----------
# Eigen Value = -1.406390
# Eigen Vector :  [-0.23178246  0.73639557 -0.81985647  0.03156171  1.         -1.18243543
#   0.30803272  0.67572471 -0.84975702  0.36450037]
# Error = 0.405542
#
# Iteration 191
# ----------
# Eigen Value = -1.005875
# Eigen Vector :  [ 0.19706553 -0.62418557  0.69325324 -0.02461738 -0.84779927  1.
#  -0.25869667 -0.57300818  0.71875982 -0.30778834]
# Error = 0.4005146
#
# Iteration 192
# ----------
# Eigen Value = -1.399482
# Eigen Vector :  [-0.23309338  0.7360914  -0.81559892  0.02655545  1.         -1.17666376
#   0.3022953   0.67602703 -0.84586645  0.36161252]
# Error = 0.3936067
#
# Iteration 193
# ----------
# Eigen Value = -1.010778
# Eigen Vector :  [ 0.19911532 -0.62694707  0.69303865 -0.02054499 -0.85189597  1.
#  -0.25514325 -0.57603016  0.71897573 -0.30685786]
# Error = 0.3887035
#
# Iteration 194
# ----------
# Eigen Value = -1.392810
# Eigen Vector :  [-0.23435958  0.7357976  -0.81148664  0.02171998  1.         -1.17108899
#   0.29675363  0.67631904 -0.84210862  0.3588232 ]
# Error = 0.3820312
#
# Iteration 195
# ----------
# Eigen Value = -1.015560
# Eigen Vector :  [ 0.20111423 -0.62964004  0.69282939 -0.01657367 -0.85589101  1.
#  -0.25167802 -0.57897715  0.71918627 -0.30595047]
# Error = 0.3772497
#
# Iteration 196
# ----------
# Eigen Value = -1.386364
# Eigen Vector :  [-0.23558277  0.73551378 -0.80751399  0.01704872  1.         -1.16570354
#   0.29140014  0.67660114 -0.83847839  0.35612859]
# Error = 0.370804
#
# Iteration 197
# ----------
# Eigen Value = -1.020222
# Eigen Vector :  [ 0.2030633  -0.63226587  0.69262535 -0.01270136 -0.85978644  1.
#  -0.24829918 -0.58185066  0.71939156 -0.3050657 ]
# Error = 0.3661417
#
# Iteration 198
# ----------
# Eigen Value = -1.380136
# Eigen Vector :  [-0.23676462  0.73523955 -0.80367564  0.01253537  1.         -1.16050014
#   0.28622762  0.6768737  -0.83497089  0.35352508]
# Error = 0.359914
#
# Iteration 199
# ----------
# Eigen Value = -1.024768
# Eigen Vector :  [ 0.20496356 -0.63482594  0.69242641 -0.00892603 -0.86358431  1.
#  -0.24500497 -0.5846522   0.71959172 -0.30420309]
# Error = 0.3553684
#
# Iteration 200
# ----------
# Eigen Value = -1.374118
# Eigen Vector :  [-0.23790669  0.73497456 -0.79996648  0.00817392  1.         -1.15547187
#   0.28122919  0.67713708 -0.83158143  0.35100919]
# Error = 0.3493502
#
# Iteration 201
# ----------
# Eigen Value = -1.029199
# Eigen Vector :  [ 0.20681602 -0.63732161  0.69223248 -0.00524566 -0.86728665  1.
#  -0.24179361 -0.58738328  0.71978683 -0.30336218]
# Error = 0.344919
#
# Iteration 202
# ----------
# Eigen Value = -1.368302
# Eigen Vector :  [-0.23901049  0.73471844 -0.79638162  0.00395864  1.         -1.1506121
#   0.27639827  0.67739164 -0.82830556  0.34857761]
# Error = 0.3391026
#
# Iteration 203
# ----------
# Eigen Value = -1.033518
# Eigen Vector :  [ 0.20862169 -0.63975425  0.69204344 -0.00165826 -0.87089547  1.
#  -0.23866337 -0.59004536  0.71997702 -0.30254251]
# Error = 0.3347833
#
# Iteration 204
# ----------
# Eigen Value = -1.362679
# Eigen Vector :  [-2.40077450e-01  7.34470875e-01 -7.92916400e-01 -1.15968074e-04
#   1.00000000e+00 -1.14591453e+00  2.71728577e-01  6.77637702e-01
#  -8.25139023e-01  3.46227184e-01]
# Error = 0.3291609
#
# Iteration 205
# ----------
# Eigen Value = -1.037728
# Eigen Vector :  [ 0.21038156 -0.64212518  0.69185921  0.00183816 -0.87441276  1.
#  -0.23561253 -0.59263993  0.72016239 -0.30174363]
# Error = 0.3249512
#
# Iteration 206
# ----------
# Eigen Value = -1.357244
# Eigen Vector :  [-0.24110894  0.73423154 -0.78956637 -0.00405513  1.         -1.14137311
#   0.26721411  0.67787559 -0.82207774  0.34395489]
# Error = 0.3195157
#
# Iteration 207
# ----------
# Eigen Value = -1.041831
# Eigen Vector :  [ 0.21209662 -0.64443574  0.69167966  0.00524553 -0.87784048  1.
#  -0.23263938 -0.59516843  0.72034303 -0.30096509]
# Error = 0.3154132
#
# Iteration 208
# ----------
# Eigen Value = -1.351988
# Eigen Vector :  [-0.24210628  0.73400012 -0.78632725 -0.00786387  1.         -1.13698205
#   0.26284911  0.67810559 -0.81911782  0.34175783]
# Error = 0.3101577
#
# Iteration 209
# ----------
# Eigen Value = -1.045828
# Eigen Vector :  [ 0.21376783 -0.64668723  0.6915047   0.00856581 -0.88118057  1.
#  -0.22974223 -0.59763229  0.72051906 -0.30020645]
# Error = 0.3061601
#
# Iteration 210
# ----------
# Eigen Value = -1.346906
# Eigen Vector :  [-0.24307073  0.73377634 -0.78319498 -0.01154697  1.         -1.13273584
#   0.2586281   0.67832801 -0.81625553  0.33963324]
# Error = 0.3010779
#
# Iteration 211
# ----------
# Eigen Value = -1.049723
# Eigen Vector :  [ 0.21539616 -0.64888095  0.69133423  0.01180088 -0.88443497  1.
#  -0.22691942 -0.60003293  0.72069057 -0.29946728]
# Error = 0.2971828
#
# Iteration 212
# ----------
# Eigen Value = -1.341991
# Eigen Vector :  [-0.24400347  0.73355991 -0.78016565 -0.01510903  1.         -1.12862917
#   0.25454581  0.67854312 -0.81348731  0.33757847]
# Error = 0.2922677
#
# Iteration 213
# ----------
# Eigen Value = -1.053518
# Eigen Vector :  [ 0.21698256 -0.65101817  0.69116816  0.01495265 -0.88760555  1.
#  -0.22416931 -0.60237175  0.72085766 -0.29874715]
# Error = 0.2884729
#
# Iteration 214
# ----------
# Eigen Value = -1.337237
# Eigen Vector :  [-0.24490567  0.73335058 -0.77723552 -0.01855444  1.         -1.12465699
#   0.2505972   0.67875119 -0.81080974  0.335591  ]
# Error = 0.2837188
#
# Iteration 215
# ----------
# Eigen Value = -1.057215
# Eigen Vector :  [ 0.21852796 -0.65310016  0.69100637  0.01802296 -0.89069419  1.
#  -0.22149027 -0.60465012  0.72102044 -0.29804563]
# Error = 0.2800221
#
# Iteration 216
# ----------
# Eigen Value = -1.332638
# Eigen Vector :  [-0.24577843  0.73314807 -0.77440102 -0.02188742  1.         -1.12081443
#   0.24677744  0.67895247 -0.80821955  0.33366838]
# Error = 0.2754231
#
# Iteration 217
# ----------
# Eigen Value = -1.060816
# Eigen Vector :  [ 0.22003328 -0.65512816  0.69084878  0.02101364 -0.89370273  1.
#  -0.2188807  -0.60686941  0.72117899 -0.2973623 ]
# Error = 0.2718222
#
# Iteration 218
# ----------
# Eigen Value = -1.328188
# Eigen Vector :  [-0.24662281  0.73295215 -0.7716587  -0.025112    1.         -1.11709685
#   0.24308192  0.6791472  -0.80571361  0.33180829]
# Error = 0.2673728
#
# Iteration 219
# ----------
# Eigen Value = -1.064323
# Eigen Vector :  [ 0.22149943 -0.65710339  0.69069529  0.02392652 -0.89663299  1.
#  -0.21633903 -0.60903095  0.72133342 -0.29669675]
# Error = 0.2638657
#
# Iteration 220
# ----------
# Eigen Value = -1.323883
# Eigen Vector :  [-0.24743981  0.73276258 -0.76900528 -0.02823204  1.         -1.11349978
#   0.23950621  0.67933562 -0.8032889   0.3300085 ]
# Error = 0.2595604
#
# Iteration 221
# ----------
# Eigen Value = -1.067738
# Eigen Vector :  [ 0.22292732 -0.65902706  0.69054581  0.02676335 -0.89948676  1.
#  -0.21386371 -0.61113607  0.72148382 -0.29604857]
# Error = 0.2561449
#
# Iteration 222
# ----------
# Eigen Value = -1.319717
# Eigen Vector :  [-0.24823041  0.73257913 -0.7664376  -0.03125126  1.         -1.11001895
#   0.23604604  0.67951794 -0.80094254  0.32826687]
# Error = 0.2519788
#
# Iteration 223
# ----------
# Eigen Value = -1.071064
# Eigen Vector :  [ 0.22431781 -0.66090036  0.69040024  0.0295259  -0.90226581  1.
#  -0.21145321 -0.61318606  0.72163028 -0.29541736]
# Error = 0.2486526
#
# Iteration 224
# ----------
# Eigen Value = -1.315685
# Eigen Vector :  [-0.24899554  0.7324016  -0.76395265 -0.03417321  1.         -1.10665026
#   0.23269734  0.6796944  -0.79867177  0.32658135]
# Error = 0.2446208
#
# Iteration 225
# ----------
# Eigen Value = -1.074303
# Eigen Vector :  [ 0.22567178 -0.66272445  0.69025849  0.03221589 -0.90497186  1.
#  -0.20910602 -0.61518222  0.72177289 -0.29480274]
# Error = 0.241382
#
# Iteration 226
# ----------
# Eigen Value = -1.311783
# Eigen Vector :  [-0.2497361   0.73222977 -0.76154751 -0.03700131  1.         -1.10338977
#   0.2294562   0.67986519 -0.79647394  0.32494997]
# Error = 0.2374796
#
# Iteration 227
# ----------
# Eigen Value = -1.077457
# Eigen Vector :  [ 0.22699008 -0.6645005   0.69012048  0.03483502 -0.90760663  1.
#  -0.20682067 -0.61712578  0.72191175 -0.2942043 ]
# Error = 0.2343262
#
# Iteration 228
# ----------
# Eigen Value = -1.308005
# Eigen Vector :  [-0.25045293  0.73206344 -0.7592194  -0.03973883  1.         -1.1002337
#   0.22631886  0.6800305  -0.7943465   0.32337083]
# Error = 0.2305488
#
# Iteration 229
# ----------
# Eigen Value = -1.080527
# Eigen Vector :  [ 0.22827356 -0.66622962  0.68998612  0.03738496 -0.91017179  1.
#  -0.20459568 -0.619018    0.72204693 -0.29362168]
# Error = 0.2274786
#
# Iteration 230
# ----------
# Eigen Value = -1.304349
# Eigen Vector :  [-0.25114688  0.73190242 -0.75696564 -0.04238893  1.         -1.09717843
#   0.22328172  0.68019054 -0.792287    0.32184213]
# Error = 0.2238219
#
# Iteration 231
# ----------
# Eigen Value = -1.083516
# Eigen Vector :  [ 0.22952303 -0.66791293  0.68985531  0.03986734 -0.91266899  1.
#  -0.20242965 -0.62086009  0.72217854 -0.29305449]
# Error = 0.220833
#
# Iteration 232
# ----------
# Eigen Value = -1.300808
# Eigen Vector :  [-0.25181872  0.73174653 -0.75478366 -0.04495463  1.         -1.09422046
#   0.22034131  0.68034548 -0.7902931   0.32036211]
# Error = 0.2172928
#
# Iteration 233
# ----------
# Eigen Value = -1.086425
# Eigen Vector :  [ 0.23073931 -0.66955153  0.68972798  0.04228378 -0.91509986  1.
#  -0.20032115 -0.62265325  0.72230665 -0.29250237]
# Error = 0.2143833
#
# Iteration 234
# ----------
# Eigen Value = -1.297381
# Eigen Vector :  [-0.25246922  0.7315956  -0.75267099 -0.04743883  1.         -1.09135645
#   0.2174943   0.6804955  -0.78836253  0.31892911]
# Error = 0.2109555
#
# Iteration 235
# ----------
# Eigen Value = -1.089257
# Eigen Vector :  [ 0.2319232  -0.67114648  0.68960404  0.04463586 -0.91746598  1.
#  -0.19826881 -0.62439865  0.72243135 -0.29196495]
# Error = 0.2081236
#
# Iteration 236
# ----------
# Eigen Value = -1.294061
# Eigen Vector :  [-0.25309911  0.73144944 -0.75062526 -0.04984432  1.         -1.08858318
#   0.21473749  0.68064077 -0.78649312  0.3175415 ]
# Error = 0.2048043
#
# Iteration 237
# ----------
# Eigen Value = -1.092013
# Eigen Vector :  [ 0.23307547 -0.67269885  0.68948341  0.04692513 -0.91976892  1.
# ...
#  -0.12668118 -0.68527987  0.72678093 -0.2732193 ]
# Error = 3.2e-06
#
# Iteration 988
# ----------
# Eigen Value = -1.188041
# Eigen Vector :  [-0.27321871  0.72678106 -0.68528179 -0.12667892  1.         -1.00000129
#   0.12668133  0.68528077 -0.72678187  0.27321965]
# Error = 3.1e-06
#
# Iteration 989
# ----------
# Eigen Value = -1.188038
# Eigen Vector :  [ 0.27321837 -0.72678014  0.6852809   0.12667878 -0.99999873  1.
#  -0.12668115 -0.6852799   0.72678093 -0.27321929]
# Error = 3.1e-06
#
# Iteration 990
# ----------
# Eigen Value = -1.188041
# Eigen Vector :  [-0.27321872  0.72678106 -0.68528176 -0.12667895  1.         -1.00000125
#   0.12668129  0.68528077 -0.72678184  0.27321963]
# Error = 3e-06
#
# Iteration 991
# ----------
# Eigen Value = -1.188038
# Eigen Vector :  [ 0.27321839 -0.72678016  0.6852809   0.12667881 -0.99999876  1.
#  -0.12668112 -0.68527992  0.72678093 -0.27321929]
# Error = 3e-06
#
# Iteration 992
# ----------
# Eigen Value = -1.188041
# Eigen Vector :  [-0.27321873  0.72678106 -0.68528173 -0.12667899  1.         -1.00000122
#   0.12668125  0.68528077 -0.72678182  0.27321961]
# Error = 2.9e-06
#
# Iteration 993
# ----------
# Eigen Value = -1.188038
# Eigen Vector :  [ 0.2732184  -0.72678019  0.6852809   0.12667885 -0.9999988   1.
#  -0.12668108 -0.68527995  0.72678093 -0.27321928]
# Error = 2.9e-06
#
# Iteration 994
# ----------
# Eigen Value = -1.188041
# Eigen Vector :  [-0.27321874  0.72678106 -0.68528171 -0.12667902  1.         -1.00000118
#   0.12668122  0.68528077 -0.72678179  0.2732196 ]
# Error = 2.9e-06
#
# Iteration 995
# ----------
# Eigen Value = -1.188038
# Eigen Vector :  [ 0.27321842 -0.72678021  0.6852809   0.12667888 -0.99999883  1.
#  -0.12668105 -0.68527997  0.72678093 -0.27321927]
# Error = 2.8e-06
#
# Iteration 996
# ----------
# Eigen Value = -1.188040
# Eigen Vector :  [-0.27321874  0.72678106 -0.68528168 -0.12667905  1.         -1.00000115
#   0.12668118  0.68528077 -0.72678177  0.27321958]
# Error = 2.8e-06
#
# Iteration 997
# ----------
# Eigen Value = -1.188038
# Eigen Vector :  [ 0.27321844 -0.72678023  0.68528089  0.12667892 -0.99999887  1.
#  -0.12668102 -0.68528     0.72678093 -0.27321926]
# Error = 2.7e-06
#
# Iteration 998
# ----------
# Eigen Value = -1.188040
# Eigen Vector :  [-0.27321875  0.72678105 -0.68528166 -0.12667908  1.         -1.00000112
#   0.12668115  0.68528078 -0.72678175  0.27321956]
# Error = 2.7e-06
#
# Iteration 999
# ----------
# Eigen Value = -1.188038
# Eigen Vector :  [ 0.27321846 -0.72678025  0.68528089  0.12667895 -0.9999989   1.
#  -0.126681   -0.68528002  0.72678094 -0.27321925]
# Error = 2.6e-06
#
# Iteration 1000
# ----------
# Eigen Value = -1.188040
# Eigen Vector :  [-0.27321876  0.72678105 -0.68528163 -0.1266791   1.         -1.00000108
#   0.12668112  0.68528078 -0.72678172  0.27321955]
# Error = 2.6e-06
#
# Iteration 1001
# ----------
# Eigen Value = -1.188038
# Eigen Vector :  [ 0.27321847 -0.72678028  0.68528089  0.12667898 -0.99999893  1.
#  -0.12668097 -0.68528005  0.72678094 -0.27321925]
# Error = 2.6e-06
#
# Iteration 1002
# ----------
# Eigen Value = -1.188040
# Eigen Vector :  [-0.27321877  0.72678105 -0.68528161 -0.12667913  1.         -1.00000105
#   0.12668109  0.68528078 -0.7267817   0.27321953]
# Error = 2.5e-06
#
# Iteration 1003
# ----------
# Eigen Value = -1.188038
# Eigen Vector :  [ 0.27321849 -0.7267803   0.68528089  0.12667901 -0.99999896  1.
#  -0.12668094 -0.68528007  0.72678094 -0.27321924]
# Error = 2.5e-06
#
# Iteration 1004
# ----------
# Eigen Value = -1.188040
# Eigen Vector :  [-0.27321877  0.72678105 -0.68528159 -0.12667916  1.         -1.00000102
#   0.12668106  0.68528078 -0.72678168  0.27321952]
# Error = 2.5e-06
#
# Iteration 1005
# ----------
# Eigen Value = -1.188038
# Eigen Vector :  [ 0.2732185  -0.72678032  0.68528089  0.12667904 -0.99999899  1.
#  -0.12668092 -0.68528009  0.72678094 -0.27321923]
# Error = 2.4e-06
#
# Iteration 1006
# ----------
# Eigen Value = -1.188040
# Eigen Vector :  [-0.27321878  0.72678105 -0.68528157 -0.12667918  1.         -1.00000099
#   0.12668103  0.68528078 -0.72678166  0.2732195 ]
# Error = 2.4e-06
#
# Iteration 1007
# ----------
# Eigen Value = -1.188038
# Eigen Vector :  [ 0.27321852 -0.72678034  0.68528089  0.12667907 -0.99999902  1.
#  -0.12668089 -0.68528011  0.72678094 -0.27321923]
# Error = 2.4e-06
#
# Iteration 1008
# ----------
# Eigen Value = -1.188040
# Eigen Vector :  [-0.27321879  0.72678105 -0.68528154 -0.12667921  1.         -1.00000096
#   0.126681    0.68528078 -0.72678164  0.27321949]
# Error = 2.3e-06
#
# Iteration 1009
# ----------
# Eigen Value = -1.188038
# Eigen Vector :  [ 0.27321853 -0.72678036  0.68528088  0.1266791  -0.99999905  1.
#  -0.12668087 -0.68528014  0.72678094 -0.27321922]
# Error = 2.3e-06
#
# Iteration 1010
# ----------
# Eigen Value = -1.188040
# Eigen Vector :  [-0.27321879  0.72678104 -0.68528152 -0.12667923  1.         -1.00000093
#   0.12668097  0.68528079 -0.72678162  0.27321947]
# Error = 2.3e-06
#
# Iteration 1011
# ----------
# Eigen Value = -1.188038
# Eigen Vector :  [ 0.27321854 -0.72678037  0.68528088  0.12667913 -0.99999908  1.
#  -0.12668084 -0.68528016  0.72678095 -0.27321921]
# Error = 2.2e-06
#
# Iteration 1012
# ----------
# Eigen Value = -1.188040
# Eigen Vector :  [-0.2732188   0.72678104 -0.6852815  -0.12667926  1.         -1.00000091
#   0.12668094  0.68528079 -0.72678161  0.27321946]
# Error = 2.2e-06
#
# Iteration 1013
# ----------
# Eigen Value = -1.188038
# Eigen Vector :  [ 0.27321856 -0.72678039  0.68528088  0.12667915 -0.99999911  1.
#  -0.12668082 -0.68528018  0.72678095 -0.27321921]
# Error = 2.2e-06
#
# Iteration 1014
# ----------
# Eigen Value = -1.188040
# Eigen Vector :  [-0.27321881  0.72678104 -0.68528148 -0.12667928  1.         -1.00000088
#   0.12668092  0.68528079 -0.72678159  0.27321945]
# Error = 2.1e-06
#
# Iteration 1015
# ----------
# Eigen Value = -1.188038
# Eigen Vector :  [ 0.27321857 -0.72678041  0.68528088  0.12667918 -0.99999913  1.
#  -0.1266808  -0.68528019  0.72678095 -0.2732192 ]
# Error = 2.1e-06
#
# Iteration 1016
# ----------
# Eigen Value = -1.188040
# Eigen Vector :  [-0.27321881  0.72678104 -0.68528147 -0.1266793   1.         -1.00000086
#   0.12668089  0.68528079 -0.72678157  0.27321943]
# Error = 2.1e-06
#
# Iteration 1017
# ----------
# Eigen Value = -1.188038
# Eigen Vector :  [ 0.27321858 -0.72678043  0.68528088  0.12667921 -0.99999916  1.
#  -0.12668077 -0.68528021  0.72678095 -0.2732192 ]
# Error = 2e-06
#
# Iteration 1018
# ----------
# Eigen Value = -1.188040
# Eigen Vector :  [-0.27321882  0.72678104 -0.68528145 -0.12667932  1.         -1.00000083
#   0.12668087  0.68528079 -0.72678155  0.27321942]
# Error = 2e-06
#
# Iteration 1019
# ----------
# Eigen Value = -1.188038
# Eigen Vector :  [ 0.2732186  -0.72678044  0.68528088  0.12667923 -0.99999918  1.
#  -0.12668075 -0.68528023  0.72678095 -0.27321919]
# Error = 2e-06
#
# Iteration 1020
# ----------
# Eigen Value = -1.188040
# Eigen Vector :  [-0.27321882  0.72678104 -0.68528143 -0.12667934  1.         -1.00000081
#   0.12668084  0.68528079 -0.72678154  0.27321941]
# Error = 1.9e-06
#
# Iteration 1021
# ----------
# Eigen Value = -1.188038
# Eigen Vector :  [ 0.27321861 -0.72678046  0.68528088  0.12667925 -0.99999921  1.
#  -0.12668073 -0.68528025  0.72678095 -0.27321919]
# Error = 1.9e-06
#
# Iteration 1022
# ----------
# Eigen Value = -1.188040
# Eigen Vector :  [-0.27321883  0.72678104 -0.68528141 -0.12667936  1.         -1.00000078
#   0.12668082  0.68528079 -0.72678152  0.2732194 ]
# Error = 1.9e-06
#
# Iteration 1023
# ----------
# Eigen Value = -1.188038
# Eigen Vector :  [ 0.27321862 -0.72678047  0.68528088  0.12667928 -0.99999923  1.
#  -0.12668071 -0.68528027  0.72678095 -0.27321918]
# Error = 1.9e-06
#
# Iteration 1024
# ----------
# Eigen Value = -1.188040
# Eigen Vector :  [-0.27321883  0.72678103 -0.6852814  -0.12667938  1.         -1.00000076
#   0.1266808   0.68528079 -0.72678151  0.27321939]
# Error = 1.8e-06
#
# Iteration 1025
# ----------
# Eigen Value = -1.188038
# Eigen Vector :  [ 0.27321863 -0.72678049  0.68528087  0.1266793  -0.99999925  1.
#  -0.12668069 -0.68528028  0.72678096 -0.27321918]
# Error = 1.8e-06
#
# Iteration 1026
# ----------
# Eigen Value = -1.188040
# Eigen Vector :  [-0.27321884  0.72678103 -0.68528138 -0.1266794   1.         -1.00000074
#   0.12668078  0.6852808  -0.72678149  0.27321937]
# Error = 1.8e-06
#
# Iteration 1027
# ----------
# Eigen Value = -1.188038
# Eigen Vector :  [ 0.27321864 -0.7267805   0.68528087  0.12667932 -0.99999927  1.
#  -0.12668067 -0.6852803   0.72678096 -0.27321917]
# Error = 1.8e-06
#
# Iteration 1028
# ----------
# Eigen Value = -1.188040
# Eigen Vector :  [-0.27321884  0.72678103 -0.68528136 -0.12667942  1.         -1.00000072
#   0.12668076  0.6852808  -0.72678148  0.27321936]
# Error = 1.7e-06
#
# Iteration 1029
# ----------
# Eigen Value = -1.188038
# Eigen Vector :  [ 0.27321865 -0.72678052  0.68528087  0.12667934 -0.99999929  1.
#  -0.12668066 -0.68528031  0.72678096 -0.27321917]
# Error = 1.7e-06
#
# Iteration 1030
# ----------
# Eigen Value = -1.188040
# Eigen Vector :  [-0.27321885  0.72678103 -0.68528135 -0.12667944  1.         -1.0000007
#   0.12668073  0.6852808  -0.72678146  0.27321935]
# Error = 1.7e-06
#
# Iteration 1031
# ----------
# Eigen Value = -1.188038
# Eigen Vector :  [ 0.27321866 -0.72678053  0.68528087  0.12667936 -0.99999931  1.
#  -0.12668064 -0.68528033  0.72678096 -0.27321916]
# Error = 1.7e-06
#
# Iteration 1032
# ----------
# Eigen Value = -1.188040
# Eigen Vector :  [-0.27321885  0.72678103 -0.68528133 -0.12667946  1.         -1.00000068
#   0.12668071  0.6852808  -0.72678145  0.27321934]
# Error = 1.6e-06
#
# Iteration 1033
# ----------
# Eigen Value = -1.188038
# Eigen Vector :  [ 0.27321867 -0.72678055  0.68528087  0.12667938 -0.99999933  1.
#  -0.12668062 -0.68528034  0.72678096 -0.27321916]
# Error = 1.6e-06
#
# Iteration 1034
# ----------
# Eigen Value = -1.188040
# Eigen Vector :  [-0.27321886  0.72678103 -0.68528132 -0.12667947  1.         -1.00000066
#   0.12668069  0.6852808  -0.72678144  0.27321933]
# Error = 1.6e-06
#
# Iteration 1035
# ----------
# Eigen Value = -1.188038
# Eigen Vector :  [ 0.27321868 -0.72678056  0.68528087  0.1266794  -0.99999935  1.
#  -0.1266806  -0.68528036  0.72678096 -0.27321915]
# Error = 1.6e-06
#
# Iteration 1036
# ----------
# Eigen Value = -1.188040
# Eigen Vector :  [-0.27321886  0.72678103 -0.6852813  -0.12667949  1.         -1.00000064
#   0.12668068  0.6852808  -0.72678142  0.27321932]
# Error = 1.5e-06
#
# Iteration 1037
# ----------
# Eigen Value = -1.188038
# Eigen Vector :  [ 0.27321869 -0.72678057  0.68528087  0.12667942 -0.99999937  1.
#  -0.12668059 -0.68528037  0.72678096 -0.27321915]
# Error = 1.5e-06
#
# Iteration 1038
# ----------
# Eigen Value = -1.188040
# Eigen Vector :  [-0.27321887  0.72678103 -0.68528129 -0.12667951  1.         -1.00000062
#   0.12668066  0.6852808  -0.72678141  0.27321931]
# Error = 1.5e-06
#
# Iteration 1039
# ----------
# Eigen Value = -1.188038
# Eigen Vector :  [ 0.2732187  -0.72678058  0.68528087  0.12667944 -0.99999939  1.
#  -0.12668057 -0.68528039  0.72678096 -0.27321914]
# Error = 1.5e-06
#
# Iteration 1040
# ----------
# Eigen Value = -1.188040
# Eigen Vector :  [-0.27321887  0.72678103 -0.68528128 -0.12667952  1.         -1.0000006
#   0.12668064  0.6852808  -0.7267814   0.27321931]
# Error = 1.4e-06
#
# Iteration 1041
# ----------
# Eigen Value = -1.188038
# Eigen Vector :  [ 0.27321871 -0.7267806   0.68528087  0.12667946 -0.99999941  1.
#  -0.12668056 -0.6852804   0.72678096 -0.27321914]
# Error = 1.4e-06
#
# Iteration 1042
# ----------
# Eigen Value = -1.188040
# Eigen Vector :  [-0.27321887  0.72678103 -0.68528126 -0.12667954  1.         -1.00000058
#   0.12668062  0.6852808  -0.72678139  0.2732193 ]
# Error = 1.4e-06
#
# Iteration 1043
# ----------
# Eigen Value = -1.188038
# Eigen Vector :  [ 0.27321872 -0.72678061  0.68528086  0.12667947 -0.99999943  1.
#  -0.12668054 -0.68528041  0.72678096 -0.27321914]
# Error = 1.4e-06
#
# Iteration 1044
# ----------
# Eigen Value = -1.188040
# Eigen Vector :  [-0.27321888  0.72678102 -0.68528125 -0.12667955  1.         -1.00000057
#   0.12668061  0.68528081 -0.72678138  0.27321929]
# Error = 1.4e-06
#
# Iteration 1045
# ----------
# Eigen Value = -1.188038
# Eigen Vector :  [ 0.27321873 -0.72678062  0.68528086  0.12667949 -0.99999944  1.
#  -0.12668053 -0.68528042  0.72678097 -0.27321913]
# Error = 1.3e-06
#
# Iteration 1046
# ----------
# Eigen Value = -1.188040
# Eigen Vector :  [-0.27321888  0.72678102 -0.68528124 -0.12667957  1.         -1.00000055
#   0.12668059  0.68528081 -0.72678136  0.27321928]
# Error = 1.3e-06
#
# Iteration 1047
# ----------
# Eigen Value = -1.188038
# Eigen Vector :  [ 0.27321873 -0.72678063  0.68528086  0.12667951 -0.99999946  1.
#  -0.12668051 -0.68528044  0.72678097 -0.27321913]
# Error = 1.3e-06
#
# Iteration 1048
# ----------
# Eigen Value = -1.188040
# Eigen Vector :  [-0.27321888  0.72678102 -0.68528123 -0.12667958  1.         -1.00000053
#   0.12668057  0.68528081 -0.72678135  0.27321927]
# Error = 1.3e-06
#
# Iteration 1049
# ----------
# Eigen Value = -1.188038
# Eigen Vector :  [ 0.27321874 -0.72678064  0.68528086  0.12667952 -0.99999947  1.
#  -0.1266805  -0.68528045  0.72678097 -0.27321912]
# Error = 1.3e-06
#
# Iteration 1050
# ----------
# Eigen Value = -1.188040
# Eigen Vector :  [-0.27321889  0.72678102 -0.68528122 -0.12667959  1.         -1.00000052
#   0.12668056  0.68528081 -0.72678134  0.27321926]
# Error = 1.2e-06
#
# Iteration 1051
# ----------
# Eigen Value = -1.188039
# Eigen Vector :  [ 0.27321875 -0.72678065  0.68528086  0.12667954 -0.99999949  1.
#  -0.12668049 -0.68528046  0.72678097 -0.27321912]
# Error = 1.2e-06
#
# Iteration 1052
# ----------
# Eigen Value = -1.188040
# Eigen Vector :  [-0.27321889  0.72678102 -0.68528121 -0.12667961  1.         -1.0000005
#   0.12668054  0.68528081 -0.72678133  0.27321926]
# Error = 1.2e-06
#
# Iteration 1053
# ----------
# Eigen Value = -1.188039
# Eigen Vector :  [ 0.27321876 -0.72678066  0.68528086  0.12667955 -0.9999995   1.
#  -0.12668047 -0.68528047  0.72678097 -0.27321912]
# Error = 1.2e-06
#
# Iteration 1054
# ----------
# Eigen Value = -1.188040
# Eigen Vector :  [-0.27321889  0.72678102 -0.68528119 -0.12667962  1.         -1.00000049
#   0.12668053  0.68528081 -0.72678132  0.27321925]
# Error = 1.2e-06
#
# Iteration 1055
# ----------
# Eigen Value = -1.188039
# Eigen Vector :  [ 0.27321876 -0.72678067  0.68528086  0.12667956 -0.99999952  1.
#  -0.12668046 -0.68528048  0.72678097 -0.27321911]
# Error = 1.2e-06
#
# Iteration 1056
# ----------
# Eigen Value = -1.188040
# Eigen Vector :  [-0.2732189   0.72678102 -0.68528118 -0.12667963  1.         -1.00000047
#   0.12668051  0.68528081 -0.72678131  0.27321924]
# Error = 1.1e-06
#
# Iteration 1057
# ----------
# Eigen Value = -1.188039
# Eigen Vector :  [ 0.27321877 -0.72678068  0.68528086  0.12667958 -0.99999953  1.
#  -0.12668045 -0.68528049  0.72678097 -0.27321911]
# Error = 1.1e-06
#
# Iteration 1058
# ----------
# Eigen Value = -1.188040
# Eigen Vector :  [-0.2732189   0.72678102 -0.68528117 -0.12667964  1.         -1.00000046
#   0.1266805   0.68528081 -0.7267813   0.27321924]
# Error = 1.1e-06
#
# Iteration 1059
# ----------
# Eigen Value = -1.188039
# Eigen Vector :  [ 0.27321878 -0.72678069  0.68528086  0.12667959 -0.99999955  1.
#  -0.12668044 -0.6852805   0.72678097 -0.27321911]
# Error = 1.1e-06
#
# Iteration 1060
# ----------
# Eigen Value = -1.188040
# Eigen Vector :  [-0.2732189   0.72678102 -0.68528116 -0.12667966  1.         -1.00000045
#   0.12668049  0.68528081 -0.7267813   0.27321923]
# Error = 1.1e-06
#
# Iteration 1061
# ----------
# Eigen Value = -1.188039
# Eigen Vector :  [ 0.27321879 -0.7267807   0.68528086  0.12667961 -0.99999956  1.
#  -0.12668042 -0.68528051  0.72678097 -0.27321911]
# Error = 1.1e-06
#
# Iteration 1062
# ----------
# Eigen Value = -1.188040
# Eigen Vector :  [-0.27321891  0.72678102 -0.68528115 -0.12667967  1.         -1.00000043
#   0.12668047  0.68528081 -0.72678129  0.27321922]
# Error = 1e-06
#
# Iteration 1063
# ----------
# Eigen Value = -1.188039
# Eigen Vector :  [ 0.27321879 -0.72678071  0.68528086  0.12667962 -0.99999957  1.
#  -0.12668041 -0.68528052  0.72678097 -0.2732191 ]
# Error = 1e-06
#
# Iteration 1064
# ----------
# Eigen Value = -1.188040
# Eigen Vector :  [-0.27321891  0.72678102 -0.68528115 -0.12667968  1.         -1.00000042
#   0.12668046  0.68528081 -0.72678128  0.27321922]
# Error = 1e-06
#
# Iteration 1065
# ----------
# Eigen Value = -1.188039
# Eigen Vector :  [ 0.2732188  -0.72678071  0.68528086  0.12667963 -0.99999958  1.
#  -0.1266804  -0.68528053  0.72678097 -0.2732191 ]
# Error = 1e-06
#
# Iteration 1066
# ----------
# Eigen Value = -1.188040
# Eigen Vector :  [-0.27321891  0.72678102 -0.68528114 -0.12667969  1.         -1.00000041
#   0.12668045  0.68528081 -0.72678127  0.27321921]
# Error = 1e-06

# %% [markdown]
# *Using inverse power method to find smallest eigenvalue in this case was expensive and took 3243 iterations for the solution to* *converge. The smallest eigenvalue was found to be -1.188040*
# - *Eigen Value = -1.188040*
# - *Eigen Vector :  [-0.27321891, 0.72678102, -0.68528114, -0.12667969,  1. , -1.00000041, 0.12668045,  0.68528081, -0.72678127, 0.27321921]*

# %% [markdown]
# *Hence, we can see the usefulness of Power method in obtaining the dominant and smallest eigenvalues.*
